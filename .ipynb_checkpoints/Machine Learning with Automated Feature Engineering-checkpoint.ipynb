# %% [markdown]
# <img src=https://storage.googleapis.com/kaggle-datasets-images/180/384/3da2510581f9d3b902307ff8d06fe327/dataset-cover.jpg>
# ## Breast Cancer Wisconsin (Diagnostic) Data Set
# [Kaggle Data set](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data#data.csv): Predict whether the cancer is benign or malignant

# %%
import numpy as np
import pandas as pd
import featuretools as ft  # featuretools for automated feature engineering
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from featuretools import selection
from warnings import simplefilter  # import warnings filter

pd.options.mode.chained_assignment = None  #hide any pandas warnings
simplefilter(action='ignore', category=FutureWarning)  # ignore all future warnings
np.random.seed(123) #ensure reproducibility
# %matplotlib inline

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# #### 1. Download dataset from [Kaggle](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data/downloads/data.csv/2)

# %%
# Read breast cancer data set as Pandas dataframe
df_raw = pd.read_csv("data.csv")
df_raw.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# #### 2. Clean up dataframe

# %%
# rearrange columns; remove coluum "Unnamed: 32"; set id as index
fixed_columns = [df_raw.columns[0]]+list(df_raw.columns[2:-1])+[df_raw.columns[1]]
df_data = df_raw[fixed_columns]

# %%
# Convert (M=malignant, B=benign) to (1,0)
df_data.loc[df_data.index[df_data['diagnosis']=='B'],'diagnosis'] = 0
df_data.loc[df_data.index[df_data['diagnosis']=='M'],'diagnosis'] = 1

# %%
df_data.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0         0.2419  ...          17.33           184.60      2019.0
# 1         0.1812  ...          23.41           158.80      1956.0
# 2         0.2069  ...          25.53           152.50      1709.0
# 3         0.2597  ...          26.50            98.87       567.7
# 4         0.1809  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  diagnosis
# 0          0.4601                  0.11890          1
# 1          0.2750                  0.08902          1
# 2          0.3613                  0.08758          1
# 3          0.6638                  0.17300          1
# 4          0.2364                  0.07678          1
#
# [5 rows x 32 columns]

# %% [markdown]
# #### Column Description
# diagnosis: The diagnosis of breast tissues (M = malignant, B = benign)
# radius: Distances from center to points on the perimeter
# texture: Standard deviation of gray-scale values
# perimeter: Mean size of the core tumor
# smoothness: Local variation in radius lengths
# compactness: perimeter^2 / area - 1.0
# concavity: Sverity of concave portions of the contour
# concave points: Number of concave portions of the contour
# fractal_dimension: "coastline approximation" - 1

# %% [markdown]
# #### 3. Count the case number of benign and malignant

# %%
plt.figure(figsize=(6,2))
ax = sns.countplot(y='diagnosis', data=df_data)
ax.set_yticklabels(['benign','malignant'])
# Out:
# [Text(0, 0, 'benign'), Text(0, 0, 'malignant')]

# %%
df_data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  texture_worst  perimeter_worst   area_worst  \
# count     569.000000  ...     569.000000       569.000000   569.000000
# mean        0.181162  ...      25.677223       107.261213   880.583128
# std         0.027414  ...       6.146258        33.602542   569.356993
# min         0.106000  ...      12.020000        50.410000   185.200000
# 25%         0.161900  ...      21.080000        84.110000   515.300000
# 50%         0.179200  ...      25.410000        97.660000   686.500000
# 75%         0.195700  ...      29.720000       125.400000  1084.000000
# max         0.304000  ...      49.540000       251.200000  4254.000000
#
#        smoothness_worst  compactness_worst  concavity_worst  \
# count        569.000000         569.000000       569.000000
# mean           0.132369           0.254265         0.272188
# std            0.022832           0.157336         0.208624
# min            0.071170           0.027290         0.000000
# 25%            0.116600           0.147200         0.114500
# 50%            0.131300           0.211900         0.226700
# 75%            0.146000           0.339100         0.382900
# max            0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst  \
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
#         diagnosis
# count  569.000000
# mean     0.372583
# std      0.483918
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000
#
# [8 rows x 32 columns]

# %% [markdown]
# ### Compare the Performance of Machine Leanring Models

# %% [markdown]
# #### 1. Setup function for K-fold cross validation

# %%
def cross_validatoin(fold, model, X, y):
    """
    Perform K-fold cross validation
    compare the sensitivity, specificity, accuracy, and F1-score of input models
    """
    sensitivity=[]
    specificity=[]
    accuracy=[]
    F1scores=[]
    
    kf = KFold(n_splits=fold,shuffle=True) 
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index] 
        y_train, y_test = y[train_index], y[test_index]
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        cm = confusion_matrix(y_test,y_pred)
        sensitivity.append(cm[0,0]/(cm[0,0]+cm[1,0]))
        specificity.append(cm[1,1]/(cm[1,1]+cm[0,1]))
        accuracy.append(accuracy_score(y_test,y_pred))
        F1scores.append(f1_score(y_test, y_pred, pos_label=1))
        
    return [np.mean(sensitivity),np.mean(specificity),np.mean(accuracy),np.mean(F1scores)]

# %%
# Set the number of fold for cross validation
fold = 10

# %% [markdown]
# #### 2. Apply and compare machine learning models

# %%
# Prepare input matrix for machine learning models
feature_names = df_data.columns.tolist()[1:-1]
X = df_data[feature_names].values
y = df_data['diagnosis'].values

# %%
# Create dictionary to collect results
d_Model_eva = {} 

# Logistic regression
d_Model_eva['Logistic Regression'] = cross_validatoin(fold, LogisticRegression(), X, y)

# Decision tree
d_Model_eva['Decision Tree'] = cross_validatoin(fold, DecisionTreeClassifier(), X, y)

# Random forest
d_Model_eva['Random Forest'] = cross_validatoin(fold, RandomForestClassifier(), X, y)

# %% [markdown]
# #### 3. Determine the best model for each metric

# %%
# Create output dataframe
df_eva = pd.DataFrame(d_Model_eva, index=['Sensitivity','Specificity','Accuracy','F1-score'])
df_eva.round(3).T.sort_values('F1-score',ascending=False)
# Out:
#                      Sensitivity  Specificity  Accuracy  F1-score
# Random Forest              0.961        0.957     0.960     0.946
# Logistic Regression        0.952        0.949     0.951     0.930
# Decision Tree              0.939        0.875     0.914     0.880

# %% [markdown]
# ### Automated Feature Engineering
# Apply Automated Feature Engineering to further improve the performance of models

# %% [markdown]
# #### 1. Generate new features with featuretools

# %%
# Create new entityset
es = ft.EntitySet(id = 'breastcancer')

df_data_ft = df_data.loc[:,['id']+feature_names]

# Create an entity from the breast cancer dataframe
es = es.entity_from_dataframe(entity_id = 'breastcancer', dataframe = df_data_ft, index='id')

# %%
# Generate new features
df_feature_matrix, feature_defs = ft.dfs(entityset = es, target_entity = 'breastcancer',
                                      trans_primitives = ['multiply_numeric','divide_by_feature'])
df_feature_matrix.head()
# Out:
#        radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# id
# 8670         15.46         19.48          101.70      748.9          0.10920
# 8913         12.89         13.12           81.89      515.9          0.06955
# 8915         14.96         19.10           97.03      687.3          0.08992
# 9047         12.94         16.17           83.18      507.6          0.09879
# 85715        13.17         18.66           85.98      534.6          0.11580
#
#        compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# id
# 8670            0.12230         0.14660              0.08087         0.1931
# 8913            0.03729         0.02260              0.01171         0.1337
# 8915            0.09823         0.05940              0.04819         0.1879
# 9047            0.08836         0.03296              0.02390         0.1735
# 85715           0.12310         0.12260              0.07340         0.2128
#
#        fractal_dimension_mean  ...  1 / compactness_se * smoothness_worst  \
# id                             ...
# 8670                  0.05796  ...                             435.869630
# 8913                  0.05581  ...                             773.184717
# 8915                  0.05852  ...                             360.101477
# 9047                  0.06200  ...                             664.001806
# 85715                 0.06777  ...                             239.687677
#
#        1 / compactness_se * fractal_dimension_worst  \
# id
# 8670                                     840.322294
# 8913                                    1075.190779
# 8915                                     558.089281
# 9047                                     993.375181
# 85715                                    363.089221
#
#        1 / area_worst * texture_mean  1 / area_mean * symmetry_mean  \
# id
# 8670                        0.000044                       0.006915
# 8913                        0.000132                       0.014498
# 8915                        0.000065                       0.007743
# 9047                        0.000106                       0.011355
# 85715                       0.000071                       0.008790
#
#        1 / concave points_se * symmetry_worst  \
# id
# 8670                               322.493156
# 8913                               733.425769
# 8915                               284.422682
# 9047                               415.032890
# 85715                              211.037248
#
#        1 / smoothness_se * texture_worst  \
# id
# 8670                            6.163708
# 8913                           13.601789
# 8915                            7.161011
# 9047                           15.046930
# 85715                           5.477369
#
#        1 / concavity_se * fractal_dimension_worst  \
# id
# 8670                                   443.312579
# 8913                                   875.382323
# 8915                                   768.462779
# 9047                                   791.374524
# 85715                                  291.971229
#
#        1 / fractal_dimension_se * texture_se  \
# id
# 8670                              517.036374
# 8913                             1024.601712
# 8915                              374.725514
# 9047                              560.330819
# 85715                             307.148975
#
#        1 / concave points_worst * radius_se  \
# id
# 8670                              13.925827
# 8913                             121.643965
# 8915                              23.343471
# 9047                              81.768128
# 85715                             16.681547
#
#        1 / concave points_worst * fractal_dimension_worst
# id
# 8670                                           82.367126
# 8913                                          269.498993
# 8915                                           79.271916
# 9047                                          152.180151
# 85715                                          40.621476
#
# [5 rows x 930 columns]

# %%
print("Number of the new features: {}".format(df_feature_matrix.shape[1]-(len(feature_names)+1)))
# Out:
# Number of the new features: 899

# %% [markdown]
# #### 2. Remove highly correlated columns
# Drop Highly Correlated Features, the code is adapted from [work](https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/) by Chris Albon.

# %%
# Define the threshold for removing correlated variables
threshold = 0.99

# %%
# Get correlation of each variables
corr_matrix = df_feature_matrix.corr().abs()
# Upper triangle of correlations
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper.head()
# Out:
#                  radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean              NaN      0.323782        0.997855   0.987357
# texture_mean             NaN           NaN        0.329533   0.321086
# perimeter_mean           NaN           NaN             NaN   0.986507
# area_mean                NaN           NaN             NaN        NaN
# smoothness_mean          NaN           NaN             NaN        NaN
#
#                  smoothness_mean  compactness_mean  concavity_mean  \
# radius_mean             0.170581          0.506124        0.676764
# texture_mean            0.023389          0.236702        0.302418
# perimeter_mean          0.207278          0.556936        0.716136
# area_mean               0.177028          0.498502        0.685983
# smoothness_mean              NaN          0.659123        0.521984
#
#                  concave points_mean  symmetry_mean  fractal_dimension_mean  \
# radius_mean                 0.822529       0.147741                0.311631
# texture_mean                0.293464       0.071401                0.076437
# perimeter_mean              0.850977       0.183027                0.261477
# area_mean                   0.823269       0.151293                0.283110
# smoothness_mean             0.553695       0.557775                0.584792
#
#                  ...  1 / compactness_se * smoothness_worst  \
# radius_mean      ...                               0.226407
# texture_mean     ...                               0.152196
# perimeter_mean   ...                               0.258245
# area_mean        ...                               0.224903
# smoothness_mean  ...                               0.484762
#
#                  1 / compactness_se * fractal_dimension_worst  \
# radius_mean                                          0.214248
# texture_mean                                         0.169659
# perimeter_mean                                       0.248642
# area_mean                                            0.213706
# smoothness_mean                                      0.441737
#
#                  1 / area_worst * texture_mean  1 / area_mean * symmetry_mean  \
# radius_mean                           0.803844                       0.860980
# texture_mean                          0.584426                       0.266698
# perimeter_mean                        0.800758                       0.862062
# area_mean                             0.740699                       0.794502
# smoothness_mean                       0.069851                       0.242121
#
#                  1 / concave points_se * symmetry_worst  \
# radius_mean                                    0.331734
# texture_mean                                   0.196852
# perimeter_mean                                 0.360487
# area_mean                                      0.323044
# smoothness_mean                                0.490604
#
#                  1 / smoothness_se * texture_worst  \
# radius_mean                               0.004691
# texture_mean                              0.497627
# perimeter_mean                            0.025431
# area_mean                                 0.041593
# smoothness_mean                           0.331656
#
#                  1 / concavity_se * fractal_dimension_worst  \
# radius_mean                                        0.164526
# texture_mean                                       0.124594
# perimeter_mean                                     0.181661
# area_mean                                          0.161885
# smoothness_mean                                    0.260205
#
#                  1 / fractal_dimension_se * texture_se  \
# radius_mean                                   0.008111
# texture_mean                                  0.349183
# perimeter_mean                                0.022016
# area_mean                                     0.024590
# smoothness_mean                               0.330673
#
#                  1 / concave points_worst * radius_se  \
# radius_mean                                  0.444322
# texture_mean                                 0.199020
# perimeter_mean                               0.460127
# area_mean                                    0.417776
# smoothness_mean                              0.401903
#
#                  1 / concave points_worst * fractal_dimension_worst
# radius_mean                                               0.360355
# texture_mean                                              0.153297
# perimeter_mean                                            0.380166
# area_mean                                                 0.337740
# smoothness_mean                                           0.376197
#
# [5 rows x 930 columns]

# %%
# Select columns with correlations above threshold
col_to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
print('{} columns with correlation > {}:\n-{}'.format(len(col_to_drop),threshold,"\n-".join(col_to_drop)))
# Out:
# 235 columns with correlation > 0.99:
# -perimeter_mean
# -perimeter_worst
# -compactness_mean * perimeter_mean
# -compactness_mean * radius_worst
# -area_worst * radius_worst
# -perimeter_mean * perimeter_worst
# -radius_mean * smoothness_se
# -compactness_se * perimeter_worst
# -area_se * perimeter_worst
# -concave points_worst * radius_worst
# -concavity_worst * perimeter_worst
# -radius_worst * smoothness_worst
# -concavity_se * perimeter_mean
# -compactness_se * perimeter_mean
# -radius_mean * texture_worst
# -area_mean * radius_mean
# -radius_mean * symmetry_mean
# -concavity_mean * perimeter_worst
# -concavity_se * radius_worst
# -perimeter_worst * symmetry_worst
# -area_mean * radius_worst
# -perimeter_mean * radius_mean
# -perimeter_worst * radius_worst
# -fractal_dimension_se * perimeter_mean
# -area_mean * radius_se
# -radius_mean * radius_worst
# -concavity_se * radius_mean
# -perimeter_mean * texture_mean
# -area_mean * perimeter_worst
# -concave points_worst * perimeter_worst
# -concavity_mean * texture_worst
# -area_se * radius_mean
# -area_se * radius_worst
# -concave points_se * radius_worst
# -concave points_worst * perimeter_mean
# -perimeter_mean * symmetry_se
# -concavity_mean * radius_worst
# -concave points_se * radius_mean
# -perimeter_se * radius_worst
# -concave points_mean * radius_mean
# -compactness_mean * radius_mean
# -concavity_se * texture_mean
# -fractal_dimension_se * perimeter_worst
# -radius_worst * smoothness_mean
# -perimeter_worst * radius_se
# -concave points_mean * perimeter_mean
# -perimeter_worst * smoothness_se
# -perimeter_worst * texture_mean
# -radius_mean * radius_se
# -fractal_dimension_mean * perimeter_worst
# -concavity_worst * radius_mean
# -compactness_worst * radius_mean
# -perimeter_mean * radius_se
# -area_mean * perimeter_se
# -area_worst * perimeter_mean
# -concave points_se * perimeter_worst
# -perimeter_mean * radius_worst
# -area_se * perimeter_se
# -concavity_worst * perimeter_mean
# -concave points_mean * perimeter_worst
# -radius_mean * texture_se
# -perimeter_mean * symmetry_worst
# -perimeter_mean * smoothness_worst
# -perimeter_worst * texture_se
# -radius_worst * symmetry_se
# -perimeter_mean * perimeter_se
# -fractal_dimension_mean * perimeter_mean
# -fractal_dimension_worst * radius_mean
# -perimeter_worst * texture_worst
# -radius_worst * symmetry_mean
# -compactness_worst * radius_worst
# -fractal_dimension_worst * radius_worst
# -area_worst * radius_se
# -concavity_mean * radius_mean
# -fractal_dimension_se * radius_mean
# -compactness_worst * perimeter_mean
# -area_worst * perimeter_worst
# -perimeter_mean * smoothness_mean
# -compactness_se * radius_worst
# -1 / perimeter_mean
# -1 / perimeter_worst
# -1 / concavity_mean * perimeter_mean
# -1 / area_mean * concavity_mean
# -1 / concavity_worst * radius_worst
# -1 / perimeter_worst * radius_mean
# -1 / concavity_se * symmetry_worst
# -1 / concave points_se * concavity_worst
# -1 / concavity_se * radius_se
# -1 / concave points_mean * concavity_worst
# -1 / compactness_mean * perimeter_mean
# -1 / compactness_mean * radius_worst
# -1 / concavity_se * fractal_dimension_mean
# -1 / area_worst * radius_worst
# -1 / concavity_mean * fractal_dimension_worst
# -1 / concave points_mean * smoothness_worst
# -1 / perimeter_mean * perimeter_worst
# -1 / concavity_worst * smoothness_mean
# -1 / concavity_worst * texture_mean
# -1 / concavity_mean * symmetry_mean
# -1 / radius_mean * smoothness_se
# -1 / concavity_se * symmetry_mean
# -1 / concavity_mean * symmetry_worst
# -1 / compactness_se * perimeter_worst
# -1 / area_se * perimeter_worst
# -1 / concavity_se * perimeter_worst
# -1 / concave points_worst * radius_worst
# -1 / concavity_worst * perimeter_worst
# -1 / radius_worst * texture_mean
# -1 / radius_worst * smoothness_worst
# -1 / concavity_se * perimeter_mean
# -1 / compactness_se * perimeter_mean
# -1 / radius_mean * texture_worst
# -1 / concavity_worst * fractal_dimension_mean
# -1 / area_mean * radius_mean
# -1 / radius_mean * symmetry_mean
# -1 / concavity_mean * perimeter_worst
# -1 / concavity_se * concavity_worst
# -1 / concavity_se * radius_worst
# -1 / perimeter_worst * symmetry_worst
# -1 / area_mean * radius_worst
# -1 / perimeter_mean * radius_mean
# -1 / radius_se * radius_worst
# -1 / perimeter_worst * radius_worst
# -1 / fractal_dimension_se * perimeter_mean
# -1 / area_se * concavity_worst
# -1 / area_mean * radius_se
# -1 / radius_mean * symmetry_worst
# -1 / compactness_mean * concavity_se
# -1 / concave points_worst * texture_mean
# -1 / radius_mean * radius_worst
# -1 / concavity_se * radius_mean
# -1 / fractal_dimension_mean * fractal_dimension_se
# -1 / perimeter_mean * texture_mean
# -1 / area_mean * perimeter_worst
# -1 / concave points_worst * perimeter_worst
# -1 / concavity_mean * texture_worst
# -1 / radius_mean * smoothness_worst
# -1 / concave points_mean * concavity_se
# -1 / fractal_dimension_worst * perimeter_worst
# -1 / concavity_worst * symmetry_worst
# -1 / concavity_worst * smoothness_worst
# -1 / area_se * radius_mean
# -1 / area_se * radius_worst
# -1 / compactness_se * texture_worst
# -1 / concave points_se * radius_worst
# -1 / radius_worst * texture_worst
# -1 / perimeter_mean * texture_se
# -1 / concave points_mean * fractal_dimension_mean
# -1 / concavity_mean * smoothness_worst
# -1 / compactness_worst * concavity_mean
# -1 / concavity_worst * fractal_dimension_worst
# -1 / concave points_worst * perimeter_mean
# -1 / concavity_se * smoothness_worst
# -1 / perimeter_mean * symmetry_se
# -1 / area_worst * compactness_mean
# -1 / concavity_mean * radius_worst
# -1 / concave points_se * radius_mean
# -1 / perimeter_se * radius_mean
# -1 / concavity_mean * radius_se
# -1 / concavity_se * smoothness_mean
# -1 / perimeter_se * radius_worst
# -1 / concave points_mean * radius_mean
# -1 / area_worst * texture_worst
# -1 / compactness_mean * radius_mean
# -1 / concave points_mean * concavity_mean
# -1 / concavity_se * texture_mean
# -1 / fractal_dimension_se * perimeter_worst
# -1 / radius_worst * smoothness_mean
# -1 / area_mean * concavity_se
# -1 / radius_worst * smoothness_se
# -1 / perimeter_worst * radius_se
# -1 / concavity_worst * symmetry_mean
# -1 / concave points_mean * perimeter_mean
# -1 / perimeter_worst * smoothness_se
# -1 / compactness_worst * perimeter_se
# -1 / concave points_worst * fractal_dimension_mean
# -1 / concavity_worst * texture_worst
# -1 / perimeter_worst * texture_mean
# -1 / radius_mean * radius_se
# -1 / fractal_dimension_mean * perimeter_worst
# -1 / concavity_worst * radius_mean
# -1 / compactness_worst * radius_mean
# -1 / area_mean * concavity_worst
# -1 / concavity_mean * perimeter_se
# -1 / perimeter_mean * radius_se
# -1 / area_mean * perimeter_se
# -1 / area_worst * perimeter_mean
# -1 / compactness_se * fractal_dimension_mean
# -1 / concave points_se * perimeter_worst
# -1 / perimeter_mean * radius_worst
# -1 / area_worst * concavity_worst
# -1 / concave points_mean * fractal_dimension_worst
# -1 / concavity_worst * perimeter_se
# -1 / area_mean * compactness_se
# -1 / concave points_mean * symmetry_mean
# -1 / concavity_worst * perimeter_mean
# -1 / area_mean * compactness_worst
# -1 / concave points_mean * perimeter_worst
# -1 / radius_mean * texture_se
# -1 / perimeter_mean * symmetry_worst
# -1 / concavity_mean * fractal_dimension_mean
# -1 / perimeter_mean * smoothness_worst
# -1 / perimeter_worst * texture_se
# -1 / area_mean * concave points_se
# -1 / area_mean * concave points_worst
# -1 / radius_worst * symmetry_se
# -1 / concave points_mean * texture_mean
# -1 / perimeter_mean * perimeter_se
# -1 / area_mean * concave points_mean
# -1 / fractal_dimension_mean * perimeter_mean
# -1 / fractal_dimension_worst * radius_mean
# -1 / perimeter_worst * texture_worst
# -1 / area_worst * concavity_se
# -1 / radius_worst * symmetry_mean
# -1 / compactness_worst * fractal_dimension_mean
# -1 / compactness_worst * radius_worst
# -1 / area_se * area_worst
# -1 / fractal_dimension_worst * radius_worst
# -1 / area_worst * radius_se
# -1 / concavity_mean * radius_mean
# -1 / fractal_dimension_se * radius_mean
# -1 / compactness_worst * perimeter_mean
# -1 / area_worst * perimeter_worst
# -1 / concavity_se * perimeter_se
# -1 / perimeter_mean * smoothness_mean
# -1 / compactness_se * perimeter_se
# -1 / compactness_se * radius_worst
# -1 / compactness_worst * texture_worst
# -1 / concavity_mean * smoothness_mean
# -1 / concave points_worst * smoothness_mean
# -1 / compactness_mean * concavity_worst
# -1 / compactness_se * smoothness_worst
# -1 / compactness_se * fractal_dimension_worst
# -1 / concavity_se * fractal_dimension_worst
# -1 / concave points_worst * fractal_dimension_worst

# %%
df_feature_matrix_dropcorr = df_feature_matrix.drop(columns = col_to_drop)
df_feature_matrix_dropcorr.head()
# Out:
#        radius_mean  texture_mean  area_mean  smoothness_mean  \
# id
# 8670         15.46         19.48      748.9          0.10920
# 8913         12.89         13.12      515.9          0.06955
# 8915         14.96         19.10      687.3          0.08992
# 9047         12.94         16.17      507.6          0.09879
# 85715        13.17         18.66      534.6          0.11580
#
#        compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# id
# 8670            0.12230         0.14660              0.08087         0.1931
# 8913            0.03729         0.02260              0.01171         0.1337
# 8915            0.09823         0.05940              0.04819         0.1879
# 9047            0.08836         0.03296              0.02390         0.1735
# 85715           0.12310         0.12260              0.07340         0.2128
#
#        fractal_dimension_mean  radius_se  ...  \
# id                                        ...
# 8670                  0.05796     0.4743  ...
# 8913                  0.05581     0.1532  ...
# 8915                  0.05852     0.2877  ...
# 9047                  0.06200     0.1458  ...
# 85715                 0.06777     0.2871  ...
#
#        1 / perimeter_se * smoothness_worst  \
# id
# 8670                              2.090596
# 8913                              9.326757
# 8915                              3.508128
# 9047                              8.553808
# 85715                             2.951557
#
#        1 / compactness_mean * smoothness_mean  \
# id
# 8670                                74.877426
# 8913                               385.576434
# 8915                               113.213850
# 9047                               114.559552
# 85715                               70.150923
#
#        1 / perimeter_se * smoothness_se  1 / compactness_worst * symmetry_se  \
# id
# 8670                          51.795866                           299.005686
# 8913                         189.571124                           538.504992
# 8915                          86.387327                           216.841658
# 9047                         347.248447                           273.115096
# 85715                         80.702408                           137.715666
#
#        1 / area_worst * texture_mean  1 / area_mean * symmetry_mean  \
# id
# 8670                        0.000044                       0.006915
# 8913                        0.000132                       0.014498
# 8915                        0.000065                       0.007743
# 9047                        0.000106                       0.011355
# 85715                       0.000071                       0.008790
#
#        1 / concave points_se * symmetry_worst  \
# id
# 8670                               322.493156
# 8913                               733.425769
# 8915                               284.422682
# 9047                               415.032890
# 85715                              211.037248
#
#        1 / smoothness_se * texture_worst  \
# id
# 8670                            6.163708
# 8913                           13.601789
# 8915                            7.161011
# 9047                           15.046930
# 85715                           5.477369
#
#        1 / fractal_dimension_se * texture_se  \
# id
# 8670                              517.036374
# 8913                             1024.601712
# 8915                              374.725514
# 9047                              560.330819
# 85715                             307.148975
#
#        1 / concave points_worst * radius_se
# id
# 8670                              13.925827
# 8913                             121.643965
# 8915                              23.343471
# 9047                              81.768128
# 85715                             16.681547
#
# [5 rows x 695 columns]

# %% [markdown]
# #### 3. Remove columns with missing values or with too little information

# %%
# Remove columns with missing values
df_feature_matrix_dropcorr.replace([np.inf, -np.inf], np.nan, inplace=True)
col_without_nan = df_feature_matrix_dropcorr.columns[~df_feature_matrix_dropcorr.isna().any()]
df_feature_matrix_dropcorr_dropnan = df_feature_matrix_dropcorr[col_without_nan]

# Remove columns with too little information (less than ten distinct values)
selection.remove_low_information_features(df_feature_matrix_dropcorr_dropnan)

df_feature_matrix_dropcorr_dropnan.head()
# Out:
#        radius_mean  texture_mean  area_mean  smoothness_mean  \
# id
# 8670         15.46         19.48      748.9          0.10920
# 8913         12.89         13.12      515.9          0.06955
# 8915         14.96         19.10      687.3          0.08992
# 9047         12.94         16.17      507.6          0.09879
# 85715        13.17         18.66      534.6          0.11580
#
#        compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# id
# 8670            0.12230         0.14660              0.08087         0.1931
# 8913            0.03729         0.02260              0.01171         0.1337
# 8915            0.09823         0.05940              0.04819         0.1879
# 9047            0.08836         0.03296              0.02390         0.1735
# 85715           0.12310         0.12260              0.07340         0.2128
#
#        fractal_dimension_mean  radius_se  ...  \
# id                                        ...
# 8670                  0.05796     0.4743  ...
# 8913                  0.05581     0.1532  ...
# 8915                  0.05852     0.2877  ...
# 9047                  0.06200     0.1458  ...
# 85715                 0.06777     0.2871  ...
#
#        1 / smoothness_mean * texture_se  1 / area_se * symmetry_mean  \
# id
# 8670                          11.652257                     0.107197
# 8913                          30.657026                     0.589861
# 8915                          11.731009                     0.213992
# 9047                          11.185063                     0.507367
# 85715                          9.662726                     0.193783
#
#        1 / perimeter_se * smoothness_worst  \
# id
# 8670                              2.090596
# 8913                              9.326757
# 8915                              3.508128
# 9047                              8.553808
# 85715                             2.951557
#
#        1 / compactness_mean * smoothness_mean  \
# id
# 8670                                74.877426
# 8913                               385.576434
# 8915                               113.213850
# 9047                               114.559552
# 85715                               70.150923
#
#        1 / perimeter_se * smoothness_se  1 / compactness_worst * symmetry_se  \
# id
# 8670                          51.795866                           299.005686
# 8913                         189.571124                           538.504992
# 8915                          86.387327                           216.841658
# 9047                         347.248447                           273.115096
# 85715                         80.702408                           137.715666
#
#        1 / area_worst * texture_mean  1 / area_mean * symmetry_mean  \
# id
# 8670                        0.000044                       0.006915
# 8913                        0.000132                       0.014498
# 8915                        0.000065                       0.007743
# 9047                        0.000106                       0.011355
# 85715                       0.000071                       0.008790
#
#        1 / smoothness_se * texture_worst  \
# id
# 8670                            6.163708
# 8913                           13.601789
# 8915                            7.161011
# 9047                           15.046930
# 85715                           5.477369
#
#        1 / fractal_dimension_se * texture_se
# id
# 8670                              517.036374
# 8913                             1024.601712
# 8915                              374.725514
# 9047                              560.330819
# 85715                             307.148975
#
# [5 rows x 604 columns]

# %%
print("{} features are removed because they contain missing values or contain too little information.".format(df_feature_matrix_dropcorr.shape[1] - df_feature_matrix_dropcorr_dropnan.shape[1]))
# Out:
# 91 features are removed because they contain missing values or contain too little information.

# %% [markdown]
# ### Compare the Performance of Machine Leanring Models (with Feature Engineering)
# Apply K-fold cross validation to compare the performance after feature engineering with featuretools

# %% [markdown]
# #### 1. Add diagnosis column back to the feature matrix

# %%
df_outcomes = df_data.loc[:,['id','diagnosis']]
df_outcomes.set_index('id',inplace=True)

df_feature_matrix_outcomes = pd.merge(df_feature_matrix_dropcorr_dropnan,df_outcomes,
                                      left_index=True, right_index=True)
df_feature_matrix_outcomes.head()
# Out:
#        radius_mean  texture_mean  area_mean  smoothness_mean  \
# id
# 8670         15.46         19.48      748.9          0.10920
# 8913         12.89         13.12      515.9          0.06955
# 8915         14.96         19.10      687.3          0.08992
# 9047         12.94         16.17      507.6          0.09879
# 85715        13.17         18.66      534.6          0.11580
#
#        compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# id
# 8670            0.12230         0.14660              0.08087         0.1931
# 8913            0.03729         0.02260              0.01171         0.1337
# 8915            0.09823         0.05940              0.04819         0.1879
# 9047            0.08836         0.03296              0.02390         0.1735
# 85715           0.12310         0.12260              0.07340         0.2128
#
#        fractal_dimension_mean  radius_se  ...  1 / area_se * symmetry_mean  \
# id                                        ...
# 8670                  0.05796     0.4743  ...                     0.107197
# 8913                  0.05581     0.1532  ...                     0.589861
# 8915                  0.05852     0.2877  ...                     0.213992
# 9047                  0.06200     0.1458  ...                     0.507367
# 85715                 0.06777     0.2871  ...                     0.193783
#
#        1 / perimeter_se * smoothness_worst  \
# id
# 8670                              2.090596
# 8913                              9.326757
# 8915                              3.508128
# 9047                              8.553808
# 85715                             2.951557
#
#        1 / compactness_mean * smoothness_mean  \
# id
# 8670                                74.877426
# 8913                               385.576434
# 8915                               113.213850
# 9047                               114.559552
# 85715                               70.150923
#
#        1 / perimeter_se * smoothness_se  1 / compactness_worst * symmetry_se  \
# id
# 8670                          51.795866                           299.005686
# 8913                         189.571124                           538.504992
# 8915                          86.387327                           216.841658
# 9047                         347.248447                           273.115096
# 85715                         80.702408                           137.715666
#
#        1 / area_worst * texture_mean  1 / area_mean * symmetry_mean  \
# id
# 8670                        0.000044                       0.006915
# 8913                        0.000132                       0.014498
# 8915                        0.000065                       0.007743
# 9047                        0.000106                       0.011355
# 85715                       0.000071                       0.008790
#
#        1 / smoothness_se * texture_worst  \
# id
# 8670                            6.163708
# 8913                           13.601789
# 8915                            7.161011
# 9047                           15.046930
# 85715                           5.477369
#
#        1 / fractal_dimension_se * texture_se  diagnosis
# id
# 8670                              517.036374          1
# 8913                             1024.601712          0
# 8915                              374.725514          0
# 9047                              560.330819          0
# 85715                             307.148975          1
#
# [5 rows x 605 columns]

# %% [markdown]
# #### 2. Prepare input matrix (after feature engineering) for machine learning models

# %%
# Prepare input matrix for machine learning models
feature_names_ft = df_feature_matrix_outcomes.columns.tolist()[1:-1]
X_ft = df_feature_matrix_outcomes[feature_names_ft].values
y_ft = df_feature_matrix_outcomes['diagnosis'].values

# %% [markdown]
# #### 3. Apply and compare machine learning models with k-fold cross validation

# %%
# Logistic regression
d_Model_eva['Logistic Regression (After Feature Engineering)'] = cross_validatoin(fold, LogisticRegression(), X_ft, y_ft)

# Decision tree
d_Model_eva['Decision Tree (After Feature Engineering)'] = cross_validatoin(fold, DecisionTreeClassifier(), X_ft, y_ft)

# Random forest
d_Model_eva['Random Forest (After Feature Engineering)'] = cross_validatoin(fold, RandomForestClassifier(), X_ft, y_ft)

# %%
# Create output dataframe
df_eva = pd.DataFrame(d_Model_eva, index=['Sensitivity','Specificity','Accuracy','F1-score'])
df_eva.round(3).T.sort_values('F1-score',ascending=False)
# Out:
#                                                  Sensitivity  Specificity  \
# Random Forest (After Feature Engineering)              0.961        0.979
# Random Forest                                          0.961        0.957
# Logistic Regression (After Feature Engineering)        0.965        0.948
# Logistic Regression                                    0.952        0.949
# Decision Tree (After Feature Engineering)              0.955        0.930
# Decision Tree                                          0.939        0.875
#
#                                                  Accuracy  F1-score
# Random Forest (After Feature Engineering)           0.967     0.956
# Random Forest                                       0.960     0.946
# Logistic Regression (After Feature Engineering)     0.958     0.946
# Logistic Regression                                 0.951     0.930
# Decision Tree (After Feature Engineering)           0.944     0.921
# Decision Tree                                       0.914     0.880

# %% [markdown]
# ### Conclusion

# %% [markdown]
# #### 1. The performance of each model in all evaluation metrics

# %%
# Print out conclusion
print('{}-fold cross validation shows:'.format(fold))
for index, row in df_eva.iterrows():
    print("\t- {} has the best {} score = {:.3f}.".format(df_eva.loc[index,:].idxmax(axis=1), index,
                                         df_eva.loc[index, df_eva.loc[index,:].idxmax(axis=1)]))
# Out:
# 10-fold cross validation shows:
# 	- Logistic Regression (After Feature Engineering) has the best Sensitivity score = 0.965.
# 	- Random Forest (After Feature Engineering) has the best Specificity score = 0.979.
# 	- Random Forest (After Feature Engineering) has the best Accuracy score = 0.967.
# 	- Random Forest (After Feature Engineering) has the best F1-score score = 0.956.

# %% [markdown]
# #### 2. The performance improvement of automated feature engineering

# %%
models = ['Logistic Regression','Decision Tree','Random Forest']

for model in models:
    before_fe = df_eva.loc['F1-score',model]
    after_fe = df_eva.loc['F1-score',model+" (After Feature Engineering)"]
    print('{}: Automated feature engineering improves F1-score by {:.3f}'.format(model,after_fe-before_fe))
# Out:
# Logistic Regression: Automated feature engineering improves F1-score by 0.016
# Decision Tree: Automated feature engineering improves F1-score by 0.041
# Random Forest: Automated feature engineering improves F1-score by 0.010

# %% [markdown]
# #### 3. Plot the distribution of benign or malignant group of the most important features
# Feature importance is determined by random forestc model

# %%
X_train, X_test, y_train, y_test = train_test_split(X_ft, y_ft, test_size=0.1)
RF_ft = RandomForestClassifier().fit(X_train, y_train)

# convert feature importances to dcitionary
d_RF_ft_importances = dict(zip(feature_names_ft, RF_ft.feature_importances_))

# sort the dictionary into list of tuple based on the feature importances
d_RF_ft_importances = sorted(d_RF_ft_importances.items(), key=lambda x: x[1], reverse=True)

d_RF_ft_importances
# Out:
# [('area_worst * concave points_worst', 0.09226323233551176),
#  ('area_worst * concavity_mean', 0.0864903734521362),
#  ('area_worst * texture_mean', 0.08217033485621804),
#  ('concave points_mean * texture_worst', 0.08140711240047195),
#  ('concave points_mean * radius_worst', 0.0789951678959196),
#  ('1 / area_worst * fractal_dimension_mean', 0.07898680060044175),
#  ('area_worst * symmetry_worst', 0.07783689560270751),
#  ('radius_mean * smoothness_worst', 0.07469066891397418),
#  ('area_mean * smoothness_worst', 0.07393651239717117),
#  ('area_worst * fractal_dimension_worst', 0.07233944313685879),
#  ('1 / area_worst * texture_mean', 0.009096942067147855),
#  ('1 / texture_mean * texture_worst', 0.008959073861871803),
#  ('1 / area_worst * radius_mean', 0.007741763693905339),
#  ('1 / compactness_worst * radius_se', 0.007695749672210943),
#  ('1 / area_worst * symmetry_mean', 0.007529538635890806),
#  ('1 / perimeter_worst * smoothness_worst', 0.0075073368704021235),
#  ('concave points_worst * radius_mean', 0.0066278855275388945),
#  ('1 / radius_se * texture_worst', 0.006608646336192651),
#  ('area_worst * texture_worst', 0.0063672917399330755),
#  ('concave points_worst * texture_mean', 0.006333570892380661),
#  ('1 / smoothness_worst * texture_mean', 0.005813592270012138),
#  ('1 / area_se * smoothness_mean', 0.005396191029881603),
#  ('perimeter_worst * smoothness_mean', 0.00528104107021423),
#  ('area_mean * texture_mean', 0.004561503496935111),
#  ('concave points_worst * symmetry_worst', 0.003943266303155799),
#  ('area_worst * radius_mean', 0.003780087982019597),
#  ('concavity_worst * radius_se', 0.003552002062044469),
#  ('area_se * concavity_worst', 0.0032383444721766795),
#  ('texture_se', 0.002960229034283454),
#  ('radius_worst * texture_mean', 0.0025432177699018215),
#  ('compactness_worst * texture_worst', 0.002538637217427968),
#  ('smoothness_worst * texture_mean', 0.002533614645291235),
#  ('1 / smoothness_worst', 0.0024999721211299143),
#  ('1 / area_mean * fractal_dimension_worst', 0.002457033360287473),
#  ('radius_se * smoothness_mean', 0.0024237146869305623),
#  ('1 / smoothness_mean * texture_mean', 0.002364066193853428),
#  ('1 / fractal_dimension_mean', 0.002348724410219398),
#  ('area_worst * fractal_dimension_mean', 0.002241821947378484),
#  ('concavity_mean * texture_mean', 0.0021708714685767733),
#  ('perimeter_worst * smoothness_worst', 0.0021517654372676656),
#  ('compactness_mean * texture_se', 0.0021273828477593815),
#  ('area_mean * symmetry_se', 0.0021166999782675252),
#  ('texture_mean * texture_worst', 0.0019801580085268026),
#  ('radius_mean * smoothness_mean', 0.0018856789098825228),
#  ('1 / fractal_dimension_worst * texture_mean', 0.0018428756538849164),
#  ('area_se * fractal_dimension_mean', 0.001798102698085561),
#  ('concavity_worst * fractal_dimension_mean', 0.0016395903094416184),
#  ('area_se * symmetry_worst', 0.0016151939419318875),
#  ('perimeter_se * symmetry_se', 0.0015278503923981618),
#  ('1 / compactness_mean', 0.0015271176444454995),
#  ('concave points_worst * smoothness_se', 0.001492744847383884),
#  ('1 / area_worst * symmetry_worst', 0.00146873207114171),
#  ('1 / fractal_dimension_se * fractal_dimension_worst', 0.0014409546324439945),
#  ('fractal_dimension_se * radius_worst', 0.0014199050161195273),
#  ('fractal_dimension_worst', 0.0013252446817115582),
#  ('concave points_se * smoothness_se', 0.001279186368955199),
#  ('concavity_se * symmetry_se', 0.001164102004438139),
#  ('1 / smoothness_se * symmetry_mean', 0.0011207424919008843),
#  ('concavity_worst * symmetry_mean', 0.001066588986946993),
#  ('smoothness_worst * symmetry_mean', 0.0010281124497991969),
#  ('area_worst * concave points_mean', 0.0008603896962829629),
#  ('smoothness_se * symmetry_se', 0.0008403608031428365),
#  ('perimeter_se * texture_worst', 0.000839356786318985),
#  ('1 / fractal_dimension_se * smoothness_se', 0.0008310141196072639),
#  ('1 / fractal_dimension_mean * radius_se', 0.0008080760254338775),
#  ('area_se * texture_mean', 0.0008056532929925673),
#  ('1 / area_worst * fractal_dimension_worst', 0.000802163731116828),
#  ('compactness_mean * fractal_dimension_worst', 0.0007996430165104861),
#  ('smoothness_mean * texture_worst', 0.0007923843222373076),
#  ('radius_se * texture_worst', 0.0007899265367880732),
#  ('concavity_se * perimeter_worst', 0.0007880220646178092),
#  ('area_se * symmetry_mean', 0.0007873552624287416),
#  ('symmetry_se * texture_worst', 0.0007534480919147806),
#  ('1 / area_se * fractal_dimension_worst', 0.0007508011923234844),
#  ('1 / fractal_dimension_worst * radius_se', 0.0007420322117342539),
#  ('1 / area_worst * smoothness_worst', 0.0007354872603099553),
#  ('1 / area_worst * symmetry_se', 0.0007257671852961781),
#  ('concavity_mean * perimeter_mean', 0.000724330136094842),
#  ('fractal_dimension_worst * perimeter_se', 0.000704572612033238),
#  ('radius_worst * texture_worst', 0.000704572612033238),
#  ('perimeter_se * texture_mean', 0.000704572612033238),
#  ('area_mean * fractal_dimension_mean', 0.000682546538475895),
#  ('area_se * smoothness_mean', 0.0006643600041190455),
#  ('1 / fractal_dimension_mean * symmetry_se', 0.0006576011045643552),
#  ('smoothness_mean * symmetry_se', 0.0006458992128103344),
#  ('area_worst * compactness_worst', 0.0006304176516942475),
#  ('1 / fractal_dimension_worst * symmetry_worst', 0.0006165010355290831),
#  ('1 / fractal_dimension_worst * symmetry_mean', 0.0006165010355290831),
#  ('compactness_se * smoothness_mean', 0.0006142918846283054),
#  ('1 / perimeter_se * symmetry_se', 0.000611153552330023),
#  ('compactness_se * smoothness_worst', 0.000571173583221776),
#  ('1 / smoothness_se * symmetry_se', 0.0005521852840464827),
#  ('1 / area_mean * compactness_mean', 0.000548000920470296),
#  ('1 / symmetry_worst * texture_worst', 0.0005410083239240811),
#  ('area_se * concave points_mean', 0.0005166324491459107),
#  ('concave points_mean', 0.0004339814718245411),
#  ('area_worst * compactness_mean', 0.00043059947520688956),
#  ('concave points_se * symmetry_mean', 0.00042838018741633203),
#  ('1 / area_se * perimeter_se', 0.00042743330259507867),
#  ('fractal_dimension_worst * symmetry_se', 0.0004110006903527221),
#  ('1 / perimeter_se', 0.0004110006903527221),
#  ('1 / compactness_mean * symmetry_mean', 0.00040952792308553696),
#  ('1 / fractal_dimension_se * smoothness_mean', 0.00039198616176995505),
#  ('perimeter_mean * texture_worst', 0.0003875820743290625),
#  ('1 / smoothness_worst * symmetry_se', 0.00038679429207764564),
#  ('1 / area_se * texture_mean', 0.0002729670649437326),
#  ('1 / area_se * radius_se', 0.00025531534404496113),
#  ('smoothness_se * symmetry_mean', 0.0002177328669864734),
#  ('1 / smoothness_se', 0.0002009367197080475),
#  ('1 / perimeter_se * smoothness_mean', 0.00019397466205976963),
#  ('smoothness_se * symmetry_worst', 0.00019027809738551867),
#  ('concave points_worst * concavity_worst', 0.00015007836356319989),
#  ('1 / radius_se * symmetry_worst', 0.00011288732457991173),
#  ('concave points_worst * smoothness_worst', 0.00010728181970136847),
#  ('fractal_dimension_worst * texture_worst', 8.642575487495684e-05),
#  ('fractal_dimension_worst * symmetry_worst', 7.142691017713706e-05),
#  ('1 / area_worst * texture_se', 1.3204847886695839e-05),
#  ('texture_mean', 0.0),
#  ('area_mean', 0.0),
#  ('smoothness_mean', 0.0),
#  ('compactness_mean', 0.0),
#  ('concavity_mean', 0.0),
#  ('symmetry_mean', 0.0),
#  ('fractal_dimension_mean', 0.0),
#  ('radius_se', 0.0),
#  ('perimeter_se', 0.0),
#  ('area_se', 0.0),
#  ('smoothness_se', 0.0),
#  ('compactness_se', 0.0),
#  ('concavity_se', 0.0),
#  ('concave points_se', 0.0),
#  ('symmetry_se', 0.0),
#  ('fractal_dimension_se', 0.0),
#  ('radius_worst', 0.0),
#  ('texture_worst', 0.0),
#  ('area_worst', 0.0),
#  ('smoothness_worst', 0.0),
#  ('compactness_worst', 0.0),
#  ('concavity_worst', 0.0),
#  ('concave points_worst', 0.0),
#  ('symmetry_worst', 0.0),
#  ('texture_se * texture_worst', 0.0),
#  ('fractal_dimension_se * fractal_dimension_worst', 0.0),
#  ('concavity_se * texture_se', 0.0),
#  ('smoothness_worst * texture_worst', 0.0),
#  ('area_worst * perimeter_se', 0.0),
#  ('area_mean * perimeter_mean', 0.0),
#  ('compactness_se * texture_se', 0.0),
#  ('area_se * concavity_mean', 0.0),
#  ('area_se * concave points_se', 0.0),
#  ('perimeter_mean * smoothness_se', 0.0),
#  ('fractal_dimension_mean * texture_worst', 0.0),
#  ('concave points_worst * concavity_se', 0.0),
#  ('area_mean * concavity_mean', 0.0),
#  ('area_mean * compactness_mean', 0.0),
#  ('concavity_worst * radius_worst', 0.0),
#  ('perimeter_worst * radius_mean', 0.0),
#  ('radius_worst * symmetry_worst', 0.0),
#  ('area_se * concavity_se', 0.0),
#  ('compactness_worst * texture_se', 0.0),
#  ('radius_se * texture_mean', 0.0),
#  ('area_se * concave points_worst', 0.0),
#  ('fractal_dimension_worst * texture_se', 0.0),
#  ('compactness_se * radius_mean', 0.0),
#  ('concavity_se * symmetry_worst', 0.0),
#  ('concave points_mean * smoothness_mean', 0.0),
#  ('compactness_mean * perimeter_worst', 0.0),
#  ('compactness_se * symmetry_worst', 0.0),
#  ('compactness_mean * symmetry_se', 0.0),
#  ('area_worst * symmetry_se', 0.0),
#  ('symmetry_worst * texture_se', 0.0),
#  ('concave points_se * concavity_worst', 0.0),
#  ('smoothness_worst * symmetry_worst', 0.0),
#  ('concavity_worst * smoothness_se', 0.0),
#  ('fractal_dimension_se * symmetry_worst', 0.0),
#  ('concavity_se * smoothness_se', 0.0),
#  ('concave points_worst * fractal_dimension_se', 0.0),
#  ('compactness_mean * concave points_mean', 0.0),
#  ('radius_mean * texture_mean', 0.0),
#  ('compactness_worst * smoothness_se', 0.0),
#  ('area_mean * area_worst', 0.0),
#  ('concavity_worst * symmetry_se', 0.0),
#  ('area_mean * texture_se', 0.0),
#  ('perimeter_se * smoothness_mean', 0.0),
#  ('concavity_se * radius_se', 0.0),
#  ('concave points_worst * concavity_mean', 0.0),
#  ('compactness_se * radius_se', 0.0),
#  ('compactness_se * symmetry_se', 0.0),
#  ('perimeter_se * radius_se', 0.0),
#  ('concave points_mean * concavity_worst', 0.0),
#  ('concave points_mean * perimeter_se', 0.0),
#  ('fractal_dimension_mean * radius_worst', 0.0),
#  ('compactness_worst * symmetry_worst', 0.0),
#  ('concavity_se * fractal_dimension_mean', 0.0),
#  ('area_se * compactness_se', 0.0),
#  ('fractal_dimension_se * symmetry_se', 0.0),
#  ('concavity_se * texture_worst', 0.0),
#  ('concavity_mean * concavity_worst', 0.0),
#  ('concavity_mean * fractal_dimension_worst', 0.0),
#  ('symmetry_worst * texture_worst', 0.0),
#  ('radius_se * smoothness_se', 0.0),
#  ('area_worst * concave points_se', 0.0),
#  ('fractal_dimension_mean * smoothness_se', 0.0),
#  ('concave points_mean * smoothness_worst', 0.0),
#  ('compactness_mean * concave points_worst', 0.0),
#  ('concavity_worst * smoothness_mean', 0.0),
#  ('perimeter_mean * symmetry_mean', 0.0),
#  ('fractal_dimension_mean * symmetry_mean', 0.0),
#  ('area_se * texture_worst', 0.0),
#  ('perimeter_worst * symmetry_mean', 0.0),
#  ('concavity_worst * texture_mean', 0.0),
#  ('concavity_mean * symmetry_mean', 0.0),
#  ('area_se * perimeter_mean', 0.0),
#  ('fractal_dimension_worst * smoothness_se', 0.0),
#  ('symmetry_mean * texture_mean', 0.0),
#  ('fractal_dimension_mean * symmetry_se', 0.0),
#  ('compactness_worst * concavity_se', 0.0),
#  ('perimeter_se * perimeter_worst', 0.0),
#  ('concavity_se * symmetry_mean', 0.0),
#  ('concavity_mean * symmetry_worst', 0.0),
#  ('concave points_se * fractal_dimension_mean', 0.0),
#  ('fractal_dimension_worst * texture_mean', 0.0),
#  ('fractal_dimension_worst * smoothness_worst', 0.0),
#  ('compactness_worst * smoothness_worst', 0.0),
#  ('compactness_mean * texture_worst', 0.0),
#  ('concavity_mean * smoothness_se', 0.0),
#  ('smoothness_mean * smoothness_worst', 0.0),
#  ('compactness_se * texture_mean', 0.0),
#  ('concave points_se * perimeter_mean', 0.0),
#  ('fractal_dimension_se * smoothness_se', 0.0),
#  ('concave points_mean * smoothness_se', 0.0),
#  ('smoothness_se * smoothness_worst', 0.0),
#  ('radius_worst * texture_se', 0.0),
#  ('area_worst * smoothness_worst', 0.0),
#  ('compactness_mean * radius_se', 0.0),
#  ('compactness_mean * smoothness_se', 0.0),
#  ('concave points_worst * texture_worst', 0.0),
#  ('area_mean * fractal_dimension_se', 0.0),
#  ('area_mean * symmetry_worst', 0.0),
#  ('perimeter_worst * symmetry_se', 0.0),
#  ('compactness_worst * concave points_mean', 0.0),
#  ('fractal_dimension_se * smoothness_worst', 0.0),
#  ('concave points_worst * symmetry_se', 0.0),
#  ('compactness_mean * texture_mean', 0.0),
#  ('compactness_se * concavity_worst', 0.0),
#  ('concavity_se * concavity_worst', 0.0),
#  ('perimeter_se * symmetry_mean', 0.0),
#  ('compactness_worst * radius_se', 0.0),
#  ('radius_se * symmetry_mean', 0.0),
#  ('concave points_worst * texture_se', 0.0),
#  ('radius_mean * symmetry_se', 0.0),
#  ('compactness_mean * perimeter_se', 0.0),
#  ('compactness_se * fractal_dimension_se', 0.0),
#  ('fractal_dimension_se * perimeter_se', 0.0),
#  ('radius_se * radius_worst', 0.0),
#  ('fractal_dimension_mean * smoothness_worst', 0.0),
#  ('compactness_worst * concave points_se', 0.0),
#  ('concave points_worst * perimeter_se', 0.0),
#  ('fractal_dimension_se * texture_mean', 0.0),
#  ('area_mean * texture_worst', 0.0),
#  ('concave points_se * fractal_dimension_se', 0.0),
#  ('radius_mean * symmetry_worst', 0.0),
#  ('compactness_mean * smoothness_worst', 0.0),
#  ('compactness_mean * concavity_se', 0.0),
#  ('concave points_se * smoothness_worst', 0.0),
#  ('fractal_dimension_worst * symmetry_mean', 0.0),
#  ('concave points_se * concavity_mean', 0.0),
#  ('concavity_mean * symmetry_se', 0.0),
#  ('smoothness_mean * smoothness_se', 0.0),
#  ('concave points_mean * texture_se', 0.0),
#  ('fractal_dimension_mean * perimeter_se', 0.0),
#  ('compactness_worst * symmetry_mean', 0.0),
#  ('fractal_dimension_mean * fractal_dimension_se', 0.0),
#  ('compactness_mean * concavity_mean', 0.0),
#  ('symmetry_mean * texture_se', 0.0),
#  ('fractal_dimension_worst * perimeter_mean', 0.0),
#  ('symmetry_se * symmetry_worst', 0.0),
#  ('smoothness_mean * symmetry_mean', 0.0),
#  ('symmetry_worst * texture_mean', 0.0),
#  ('smoothness_mean * symmetry_worst', 0.0),
#  ('fractal_dimension_mean * texture_mean', 0.0),
#  ('smoothness_se * texture_se', 0.0),
#  ('area_se * texture_se', 0.0),
#  ('compactness_se * concavity_mean', 0.0),
#  ('area_worst * compactness_se', 0.0),
#  ('area_se * fractal_dimension_se', 0.0),
#  ('concave points_worst * symmetry_mean', 0.0),
#  ('concave points_mean * symmetry_worst', 0.0),
#  ('fractal_dimension_mean * fractal_dimension_worst', 0.0),
#  ('fractal_dimension_se * symmetry_mean', 0.0),
#  ('symmetry_mean * symmetry_worst', 0.0),
#  ('concave points_mean * concavity_se', 0.0),
#  ('fractal_dimension_worst * perimeter_worst', 0.0),
#  ('fractal_dimension_se * texture_worst', 0.0),
#  ('concave points_se * smoothness_mean', 0.0),
#  ('concavity_worst * symmetry_worst', 0.0),
#  ('concavity_worst * smoothness_worst', 0.0),
#  ('radius_se * symmetry_worst', 0.0),
#  ('concave points_mean * concave points_se', 0.0),
#  ('compactness_se * concave points_worst', 0.0),
#  ('radius_se * smoothness_worst', 0.0),
#  ('concave points_se * concave points_worst', 0.0),
#  ('concave points_se * fractal_dimension_worst', 0.0),
#  ('compactness_se * texture_worst', 0.0),
#  ('concave points_mean * radius_se', 0.0),
#  ('fractal_dimension_mean * smoothness_mean', 0.0),
#  ('radius_se * symmetry_se', 0.0),
#  ('concavity_worst * texture_se', 0.0),
#  ('area_worst * texture_se', 0.0),
#  ('symmetry_mean * symmetry_se', 0.0),
#  ('concave points_se * concavity_se', 0.0),
#  ('perimeter_mean * texture_se', 0.0),
#  ('fractal_dimension_mean * symmetry_worst', 0.0),
#  ('concave points_mean * fractal_dimension_mean', 0.0),
#  ('concavity_mean * smoothness_worst', 0.0),
#  ('symmetry_se * texture_mean', 0.0),
#  ('concavity_mean * texture_se', 0.0),
#  ('compactness_worst * concavity_mean', 0.0),
#  ('concavity_worst * fractal_dimension_worst', 0.0),
#  ('compactness_mean * symmetry_mean', 0.0),
#  ('area_se * fractal_dimension_worst', 0.0),
#  ('symmetry_mean * texture_worst', 0.0),
#  ('area_se * smoothness_worst', 0.0),
#  ('concavity_se * smoothness_worst', 0.0),
#  ('compactness_se * concave points_mean', 0.0),
#  ('compactness_se * symmetry_mean', 0.0),
#  ('area_mean * fractal_dimension_worst', 0.0),
#  ('fractal_dimension_se * smoothness_mean', 0.0),
#  ('concave points_se * texture_worst', 0.0),
#  ('area_se * radius_se', 0.0),
#  ('compactness_worst * perimeter_worst', 0.0),
#  ('radius_se * texture_se', 0.0),
#  ('perimeter_se * radius_mean', 0.0),
#  ('concavity_mean * radius_se', 0.0),
#  ('concavity_se * smoothness_mean', 0.0),
#  ('concave points_se * symmetry_se', 0.0),
#  ('fractal_dimension_mean * radius_mean', 0.0),
#  ('area_worst * smoothness_se', 0.0),
#  ('area_mean * area_se', 0.0),
#  ('concavity_mean * fractal_dimension_se', 0.0),
#  ('area_worst * symmetry_mean', 0.0),
#  ('area_mean * smoothness_se', 0.0),
#  ('concave points_mean * concavity_mean', 0.0),
#  ('compactness_worst * smoothness_mean', 0.0),
#  ('area_se * compactness_mean', 0.0),
#  ('smoothness_worst * texture_se', 0.0),
#  ('fractal_dimension_worst * smoothness_mean', 0.0),
#  ('area_mean * concavity_se', 0.0),
#  ('concave points_se * radius_se', 0.0),
#  ('compactness_worst * concave points_worst', 0.0),
#  ('radius_worst * smoothness_se', 0.0),
#  ('compactness_worst * fractal_dimension_worst', 0.0),
#  ('compactness_se * compactness_worst', 0.0),
#  ('compactness_se * concavity_se', 0.0),
#  ('compactness_worst * perimeter_se', 0.0),
#  ('area_se * symmetry_se', 0.0),
#  ('concave points_worst * fractal_dimension_mean', 0.0),
#  ('concavity_worst * texture_worst', 0.0),
#  ('concave points_mean * symmetry_se', 0.0),
#  ('compactness_se * smoothness_se', 0.0),
#  ('compactness_se * concave points_se', 0.0),
#  ('concave points_mean * concave points_worst', 0.0),
#  ('fractal_dimension_mean * radius_se', 0.0),
#  ('compactness_worst * texture_mean', 0.0),
#  ('compactness_mean * compactness_worst', 0.0),
#  ('concavity_se * fractal_dimension_se', 0.0),
#  ('area_mean * smoothness_mean', 0.0),
#  ('perimeter_se * texture_se', 0.0),
#  ('compactness_mean * fractal_dimension_mean', 0.0),
#  ('compactness_worst * fractal_dimension_se', 0.0),
#  ('area_mean * concavity_worst', 0.0),
#  ('concavity_mean * perimeter_se', 0.0),
#  ('compactness_se * fractal_dimension_mean', 0.0),
#  ('area_worst * concavity_worst', 0.0),
#  ('perimeter_se * symmetry_worst', 0.0),
#  ('compactness_mean * compactness_se', 0.0),
#  ('fractal_dimension_se * radius_se', 0.0),
#  ('concave points_mean * fractal_dimension_worst', 0.0),
#  ('concavity_worst * perimeter_se', 0.0),
#  ('area_mean * compactness_se', 0.0),
#  ('area_se * compactness_worst', 0.0),
#  ('texture_mean * texture_se', 0.0),
#  ('concave points_mean * symmetry_mean', 0.0),
#  ('symmetry_se * texture_se', 0.0),
#  ('area_mean * compactness_worst', 0.0),
#  ('concavity_mean * fractal_dimension_mean', 0.0),
#  ('compactness_mean * fractal_dimension_se', 0.0),
#  ('area_mean * concave points_se', 0.0),
#  ('area_mean * concave points_worst', 0.0),
#  ('area_worst * fractal_dimension_se', 0.0),
#  ('fractal_dimension_worst * radius_se', 0.0),
#  ('concave points_se * perimeter_se', 0.0),
#  ('concave points_mean * texture_mean', 0.0),
#  ('area_mean * concave points_mean', 0.0),
#  ('area_se * smoothness_se', 0.0),
#  ('area_worst * concavity_se', 0.0),
#  ('concave points_se * texture_mean', 0.0),
#  ('concave points_se * texture_se', 0.0),
#  ('concavity_worst * fractal_dimension_se', 0.0),
#  ('compactness_mean * concave points_se', 0.0),
#  ('compactness_worst * fractal_dimension_mean', 0.0),
#  ('concavity_mean * concavity_se', 0.0),
#  ('area_se * area_worst', 0.0),
#  ('fractal_dimension_mean * texture_se', 0.0),
#  ('smoothness_se * texture_mean', 0.0),
#  ('compactness_worst * concavity_worst', 0.0),
#  ('concave points_mean * fractal_dimension_se', 0.0),
#  ('area_worst * smoothness_mean', 0.0),
#  ('concavity_se * perimeter_se', 0.0),
#  ('compactness_se * perimeter_se', 0.0),
#  ('compactness_mean * symmetry_worst', 0.0),
#  ('smoothness_mean * texture_mean', 0.0),
#  ('concavity_mean * smoothness_mean', 0.0),
#  ('smoothness_worst * symmetry_se', 0.0),
#  ('smoothness_mean * texture_se', 0.0),
#  ('perimeter_se * smoothness_worst', 0.0),
#  ('concave points_worst * smoothness_mean', 0.0),
#  ('compactness_mean * concavity_worst', 0.0),
#  ('compactness_mean * smoothness_mean', 0.0),
#  ('perimeter_se * smoothness_se', 0.0),
#  ('compactness_worst * symmetry_se', 0.0),
#  ('compactness_se * fractal_dimension_worst', 0.0),
#  ('area_mean * symmetry_mean', 0.0),
#  ('concave points_se * symmetry_worst', 0.0),
#  ('smoothness_se * texture_worst', 0.0),
#  ('concavity_se * fractal_dimension_worst', 0.0),
#  ('fractal_dimension_se * texture_se', 0.0),
#  ('concave points_worst * radius_se', 0.0),
#  ('concave points_worst * fractal_dimension_worst', 0.0),
#  ('1 / radius_mean', 0.0),
#  ('1 / texture_mean', 0.0),
#  ('1 / area_mean', 0.0),
#  ('1 / smoothness_mean', 0.0),
#  ('1 / symmetry_mean', 0.0),
#  ('1 / radius_se', 0.0),
#  ('1 / texture_se', 0.0),
#  ('1 / area_se', 0.0),
#  ('1 / compactness_se', 0.0),
#  ('1 / symmetry_se', 0.0),
#  ('1 / fractal_dimension_se', 0.0),
#  ('1 / radius_worst', 0.0),
#  ('1 / texture_worst', 0.0),
#  ('1 / area_worst', 0.0),
#  ('1 / compactness_worst', 0.0),
#  ('1 / symmetry_worst', 0.0),
#  ('1 / fractal_dimension_worst', 0.0),
#  ('1 / texture_se * texture_worst', 0.0),
#  ('1 / smoothness_worst * texture_worst', 0.0),
#  ('1 / area_worst * perimeter_se', 0.0),
#  ('1 / area_mean * perimeter_mean', 0.0),
#  ('1 / compactness_se * texture_se', 0.0),
#  ('1 / perimeter_mean * smoothness_se', 0.0),
#  ('1 / fractal_dimension_mean * texture_worst', 0.0),
#  ('1 / compactness_mean * fractal_dimension_worst', 0.0),
#  ('1 / radius_worst * symmetry_worst', 0.0),
#  ('1 / compactness_worst * texture_se', 0.0),
#  ('1 / radius_se * texture_mean', 0.0),
#  ('1 / smoothness_mean * symmetry_se', 0.0),
#  ('1 / fractal_dimension_worst * texture_se', 0.0),
#  ('1 / compactness_se * radius_mean', 0.0),
#  ('1 / compactness_mean * perimeter_worst', 0.0),
#  ('1 / compactness_se * symmetry_worst', 0.0),
#  ('1 / compactness_mean * symmetry_se', 0.0),
#  ('1 / fractal_dimension_se * radius_worst', 0.0),
#  ('1 / symmetry_worst * texture_se', 0.0),
#  ('1 / fractal_dimension_worst * symmetry_se', 0.0),
#  ('1 / smoothness_worst * symmetry_worst', 0.0),
#  ('1 / fractal_dimension_se * symmetry_worst', 0.0),
#  ('1 / radius_mean * texture_mean', 0.0),
#  ('1 / compactness_worst * smoothness_se', 0.0),
#  ('1 / area_mean * area_worst', 0.0),
#  ('1 / area_mean * texture_se', 0.0),
#  ('1 / compactness_se * radius_se', 0.0),
#  ('1 / compactness_se * symmetry_se', 0.0),
#  ('1 / perimeter_se * radius_se', 0.0),
#  ('1 / symmetry_se * texture_worst', 0.0),
#  ('1 / fractal_dimension_mean * radius_worst', 0.0),
#  ('1 / compactness_worst * symmetry_worst', 0.0),
#  ('1 / area_se * compactness_se', 0.0),
#  ('1 / fractal_dimension_se * symmetry_se', 0.0),
#  ('1 / radius_se * smoothness_se', 0.0),
#  ('1 / fractal_dimension_mean * smoothness_se', 0.0),
#  ('1 / area_mean * texture_mean', 0.0),
#  ('1 / radius_mean * smoothness_mean', 0.0),
#  ('1 / perimeter_mean * symmetry_mean', 0.0),
#  ('1 / fractal_dimension_mean * symmetry_mean', 0.0),
#  ('1 / area_se * texture_worst', 0.0),
#  ('1 / perimeter_worst * symmetry_mean', 0.0),
#  ('1 / perimeter_worst * smoothness_mean', 0.0),
#  ('1 / fractal_dimension_worst * perimeter_se', 0.0),
#  ('1 / area_se * perimeter_mean', 0.0),
#  ('1 / fractal_dimension_worst * smoothness_se', 0.0),
#  ('1 / symmetry_mean * texture_mean', 0.0),
#  ('1 / perimeter_se * perimeter_worst', 0.0),
#  ('1 / fractal_dimension_worst * smoothness_worst', 0.0),
#  ('1 / radius_se * smoothness_mean', 0.0),
#  ('1 / compactness_worst * smoothness_worst', 0.0),
#  ('1 / compactness_mean * texture_worst', 0.0),
#  ('1 / perimeter_mean * texture_worst', 0.0),
#  ('1 / smoothness_mean * smoothness_worst', 0.0),
#  ('1 / compactness_se * texture_mean', 0.0),
#  ('1 / smoothness_se * smoothness_worst', 0.0),
#  ('1 / radius_worst * texture_se', 0.0),
#  ('1 / compactness_mean * radius_se', 0.0),
#  ('1 / compactness_mean * smoothness_se', 0.0),
#  ('1 / area_mean * fractal_dimension_se', 0.0),
#  ('1 / area_mean * symmetry_worst', 0.0),
#  ('1 / perimeter_worst * symmetry_se', 0.0),
#  ('1 / fractal_dimension_se * smoothness_worst', 0.0),
#  ('1 / compactness_mean * texture_mean', 0.0),
#  ('1 / perimeter_se * symmetry_mean', 0.0),
#  ('1 / radius_se * symmetry_mean', 0.0),
#  ('1 / fractal_dimension_worst * texture_worst', 0.0),
#  ('1 / radius_mean * symmetry_se', 0.0),
#  ('1 / compactness_mean * perimeter_se', 0.0),
#  ('1 / compactness_se * fractal_dimension_se', 0.0),
#  ('1 / fractal_dimension_se * perimeter_se', 0.0),
#  ('1 / fractal_dimension_mean * smoothness_worst', 0.0),
#  ('1 / fractal_dimension_se * texture_mean', 0.0),
#  ('1 / area_mean * texture_worst', 0.0),
#  ('1 / compactness_mean * smoothness_worst', 0.0),
#  ('1 / smoothness_mean * smoothness_se', 0.0),
#  ('1 / fractal_dimension_mean * perimeter_se', 0.0),
#  ('1 / compactness_worst * symmetry_mean', 0.0),
#  ('1 / area_mean * fractal_dimension_mean', 0.0),
#  ('1 / symmetry_mean * texture_se', 0.0),
#  ('1 / fractal_dimension_worst * perimeter_mean', 0.0),
#  ('1 / symmetry_se * symmetry_worst', 0.0),
#  ('1 / smoothness_mean * symmetry_mean', 0.0),
#  ('1 / symmetry_worst * texture_mean', 0.0),
#  ('1 / smoothness_mean * symmetry_worst', 0.0),
#  ('1 / fractal_dimension_mean * texture_mean', 0.0),
#  ('1 / smoothness_se * texture_se', 0.0),
#  ('1 / area_se * texture_se', 0.0),
#  ('1 / area_worst * compactness_se', 0.0),
#  ('1 / area_se * fractal_dimension_se', 0.0),
#  ('1 / fractal_dimension_mean * fractal_dimension_worst', 0.0),
#  ('1 / fractal_dimension_se * symmetry_mean', 0.0),
#  ('1 / symmetry_mean * symmetry_worst', 0.0),
#  ('1 / fractal_dimension_se * texture_worst', 0.0),
#  ('1 / area_se * symmetry_worst', 0.0),
#  ('1 / radius_se * smoothness_worst', 0.0),
#  ('1 / area_mean * symmetry_se', 0.0),
#  ('1 / fractal_dimension_mean * smoothness_mean', 0.0),
#  ('1 / radius_se * symmetry_se', 0.0),
#  ('1 / symmetry_mean * symmetry_se', 0.0),
#  ('1 / fractal_dimension_mean * symmetry_worst', 0.0),
#  ('1 / area_worst * compactness_worst', 0.0),
#  ('1 / symmetry_se * texture_mean', 0.0),
#  ('1 / symmetry_mean * texture_worst', 0.0),
#  ('1 / compactness_mean * texture_se', 0.0),
#  ('1 / area_se * smoothness_worst', 0.0),
#  ('1 / compactness_se * symmetry_mean', 0.0),
#  ('1 / compactness_worst * perimeter_worst', 0.0),
#  ('1 / radius_se * texture_se', 0.0),
#  ('1 / smoothness_mean * texture_worst', 0.0),
#  ('1 / compactness_se * smoothness_mean', 0.0),
#  ('1 / fractal_dimension_mean * radius_mean', 0.0),
#  ('1 / area_worst * smoothness_se', 0.0),
#  ('1 / area_mean * area_se', 0.0),
#  ('1 / area_mean * smoothness_se', 0.0),
#  ('1 / compactness_worst * smoothness_mean', 0.0),
#  ('1 / area_se * compactness_mean', 0.0),
#  ('1 / smoothness_worst * texture_se', 0.0),
#  ('1 / fractal_dimension_worst * smoothness_mean', 0.0),
#  ('1 / smoothness_worst * symmetry_mean', 0.0),
#  ('1 / compactness_worst * fractal_dimension_worst', 0.0),
#  ('1 / compactness_se * compactness_worst', 0.0),
#  ('1 / area_se * symmetry_se', 0.0),
#  ('1 / compactness_se * smoothness_se', 0.0),
#  ('1 / smoothness_se * symmetry_worst', 0.0),
#  ('1 / compactness_worst * texture_mean', 0.0),
#  ('1 / compactness_mean * compactness_worst', 0.0),
#  ('1 / area_mean * smoothness_mean', 0.0),
#  ('1 / perimeter_se * texture_se', 0.0),
#  ('1 / compactness_mean * fractal_dimension_mean', 0.0),
#  ('1 / compactness_worst * fractal_dimension_se', 0.0),
#  ('1 / perimeter_se * symmetry_worst', 0.0),
#  ('1 / compactness_mean * compactness_se', 0.0),
#  ('1 / fractal_dimension_se * radius_se', 0.0),
#  ('1 / area_se * compactness_worst', 0.0),
#  ('1 / area_mean * smoothness_worst', 0.0),
#  ('1 / texture_mean * texture_se', 0.0),
#  ('1 / area_se * fractal_dimension_mean', 0.0),
#  ('1 / symmetry_se * texture_se', 0.0),
#  ('1 / perimeter_se * texture_mean', 0.0),
#  ('1 / perimeter_se * texture_worst', 0.0),
#  ('1 / compactness_mean * fractal_dimension_se', 0.0),
#  ('1 / area_worst * fractal_dimension_se', 0.0),
#  ('1 / area_se * smoothness_se', 0.0),
#  ('1 / fractal_dimension_mean * texture_se', 0.0),
#  ('1 / smoothness_se * texture_mean', 0.0),
#  ('1 / area_worst * smoothness_mean', 0.0),
#  ('1 / compactness_mean * symmetry_worst', 0.0),
#  ('1 / smoothness_mean * texture_se', 0.0),
#  ('1 / area_se * symmetry_mean', 0.0),
#  ('1 / perimeter_se * smoothness_worst', 0.0),
#  ('1 / compactness_mean * smoothness_mean', 0.0),
#  ('1 / perimeter_se * smoothness_se', 0.0),
#  ('1 / compactness_worst * symmetry_se', 0.0),
#  ('1 / area_mean * symmetry_mean', 0.0),
#  ('1 / smoothness_se * texture_worst', 0.0),
#  ('1 / fractal_dimension_se * texture_se', 0.0)]

# %%
def plot_feature(df_feature_matrix_outcomes,sel_features):
    
    plt.figure(figsize = (20, 10))
    for i, sel_feature in enumerate(sel_features):

        # create a new subplot for each source
        plt.subplot(2, 3, i + 1)

        # KDE plot of the most impactful feature 
        sns.kdeplot(df_feature_matrix_outcomes.loc[df_feature_matrix_outcomes['diagnosis'] == 1,sel_feature],color='red',label = 'malignant')
        sns.kdeplot(df_feature_matrix_outcomes.loc[df_feature_matrix_outcomes['diagnosis'] == 0,sel_feature],color='blue', label = 'benign')

        # Labeling of plot
        plt.xlabel(sel_feature)

# %%
top_features = [f[0] for f in d_RF_ft_importances[:6]]
plot_feature(df_feature_matrix_outcomes,top_features)
