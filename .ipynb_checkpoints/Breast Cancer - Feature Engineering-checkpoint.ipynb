# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  #for plotting
import featuretools as ft  # featuretools for automated feature engineering

from sklearn.model_selection import KFold 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from featuretools import selection
from warnings import simplefilter  # import warnings filter

pd.options.mode.chained_assignment = None  #hide any pandas warnings
simplefilter(action='ignore', category=FutureWarning)  # ignore all future warnings
np.random.seed(123) #ensure reproducibility

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# #### Column Description [Link](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data#data.csv)
# id: ID number
# diagnosis: The diagnosis of breast tissues (M = malignant, B = benign)
# radius_mean: mean of distances from center to points on the perimeter
# texture_mean: standard deviation of gray-scale values
# perimeter_mean: mean size of the core tumor
# area_mean
# smoothness_mean: mean of local variation in radius lengths
# compactness_mean: mean of perimeter^2 / area - 1.0
# concavity_mean: mean of severity of concave portions of the contour
# concave points_mean: mean for number of concave portions of the contour
# symmetry_mean
# fractal_dimension_mean: mean for "coastline approximation" - 1
# radius_se: standard error for the mean of distances from center to points on the perimeter
# texture_se: standard error for standard deviation of gray-scale values
# perimeter_se
# area_se
# smoothness_se: standard error for local variation in radius lengths
# compactness_se: standard error for perimeter^2 / area - 1.0
# concavity_se: standard error for severity of concave portions of the contour
# concave points_se: standard error for number of concave portions of the contour
# symmetry_se
# fractal_dimension_se: standard error for "coastline approximation" - 1
# radius_worst: "worst" or largest mean value for mean of distances from center to points on the perimeter
# texture_worst: "worst" or largest mean value for standard deviation of gray-scale values
# perimeter_worst
# area_worst
# smoothness_worst: "worst" or largest mean value for local variation in radius lengths
# compactness_worst: "worst" or largest mean value for perimeter^2 / area - 1.0
# concavity_worst: "worst" or largest mean value for severity of concave portions of the contour
# concave points_worst: "worst" or largest mean value for number of concave portions of the contour
# symmetry_worst
# fractal_dimension_worst: "worst" or largest mean value for "coastline approximation" - 1

# %%
# rearrange columns; remove columns of standard error and Unnamed: 32
data_columns = [df.columns[0]]+list(df.columns[2:-1])
data_columns = [c for c in data_columns if not c.endswith('_se')]
df_data = df[data_columns]
df_data.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Automated feature engineering

# %%
# Create new entityset
es = ft.EntitySet(id = 'breastcancer')

# Create an entity from the breast cancer dataframe
es = es.entity_from_dataframe(entity_id = 'breastcancer', dataframe = df_data,index = 'id')

# %%
feature_matrix, feature_defs = ft.dfs(entityset = es, target_entity = 'breastcancer',
                                      trans_primitives = ['multiply_numeric','divide_numeric_scalar'])

# %%
feature_matrix.head()
# Out:
#        radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# id
# 8670         15.46         19.48          101.70      748.9          0.10920
# 8913         12.89         13.12           81.89      515.9          0.06955
# 8915         14.96         19.10           97.03      687.3          0.08992
# 9047         12.94         16.17           83.18      507.6          0.09879
# 85715        13.17         18.66           85.98      534.6          0.11580
#
#        compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# id
# 8670            0.12230         0.14660              0.08087         0.1931
# 8913            0.03729         0.02260              0.01171         0.1337
# 8915            0.09823         0.05940              0.04819         0.1879
# 9047            0.08836         0.03296              0.02390         0.1735
# 85715           0.12310         0.12260              0.07340         0.2128
#
#        fractal_dimension_mean  ...  compactness_worst * symmetry_mean / 1  \
# id                             ...
# 8670                  0.05796  ...                               0.046228
# 8913                  0.05581  ...                               0.015335
# 8915                  0.05852  ...                               0.056934
# 9047                  0.06200  ...                               0.033971
# 85715                 0.06777  ...                               0.088652
#
#        compactness_worst * symmetry_worst / 1  \
# id
# 8670                                 0.067918
# 8913                                 0.026484
# 8915                                 0.089749
# 9047                                 0.064555
# 85715                                0.162474
#
#        concavity_worst * smoothness_worst / 1  \
# id
# 8670                                 0.058609
# 8913                                 0.011405
# 8915                                 0.023687
# 9047                                 0.021213
# 85715                                0.089407
#
#        compactness_mean * smoothness_mean / 1  \
# id
# 8670                                 0.013355
# 8913                                 0.002594
# 8915                                 0.008833
# 9047                                 0.008729
# 85715                                0.014255
#
#        concave points_worst * texture_worst / 1  \
# id
# 8670                                   3.936400
# 8913                                   0.833876
# 8915                                   3.899691
# 9047                                   1.930918
# 85715                                  5.835960
#
#        compactness_mean * radius_mean / 1  \
# id
# 8670                             1.890758
# 8913                             0.480668
# 8915                             1.469521
# 9047                             1.143378
# 85715                            1.621227
#
#        concave points_worst * radius_mean / 1  \
# id
# 8670                                 2.340644
# 8913                                 0.691677
# 8915                                 2.227544
# 9047                                 1.085407
# 85715                                2.749896
#
#        radius_mean * texture_worst / 1  area_worst * compactness_mean / 1  \
# id
# 8670                          401.9600                         141.378800
# 8913                          200.3106                          21.516330
# 8915                          391.8024                          79.546654
# 9047                          297.8788                          51.328324
# 85715                         368.1015                          93.482140
#
#        compactness_mean * concave points_worst / 1
# id
# 8670                                      0.018516
# 8913                                      0.002001
# 8915                                      0.014626
# 9047                                      0.007412
# 85715                                     0.025703
#
# [5 rows x 420 columns]

# %% [markdown]
# ### Remove Highly Correlated Columns
# Drop Highly Correlated Features, the code is adapted from [work](https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/) by Chris Albon.

# %%
# Define the threshold for removing correlated variables
threshold = 0.9

# %%
# Get correlation of each variables
corr_matrix = feature_matrix.corr().abs()
# Upper triangle of correlations
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper.head()
# Out:
#                  radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean              NaN      0.323782        0.997855   0.987357
# texture_mean             NaN           NaN        0.329533   0.321086
# perimeter_mean           NaN           NaN             NaN   0.986507
# area_mean                NaN           NaN             NaN        NaN
# smoothness_mean          NaN           NaN             NaN        NaN
#
#                  smoothness_mean  compactness_mean  concavity_mean  \
# radius_mean             0.170581          0.506124        0.676764
# texture_mean            0.023389          0.236702        0.302418
# perimeter_mean          0.207278          0.556936        0.716136
# area_mean               0.177028          0.498502        0.685983
# smoothness_mean              NaN          0.659123        0.521984
#
#                  concave points_mean  symmetry_mean  fractal_dimension_mean  \
# radius_mean                 0.822529       0.147741                0.311631
# texture_mean                0.293464       0.071401                0.076437
# perimeter_mean              0.850977       0.183027                0.261477
# area_mean                   0.823269       0.151293                0.283110
# smoothness_mean             0.553695       0.557775                0.584792
#
#                  ...  compactness_worst * symmetry_mean / 1  \
# radius_mean      ...                               0.381700
# texture_mean     ...                               0.255792
# perimeter_mean   ...                               0.426885
# area_mean        ...                               0.361595
# smoothness_mean  ...                               0.527382
#
#                  compactness_worst * symmetry_worst / 1  \
# radius_mean                                    0.331334
# texture_mean                                   0.238910
# perimeter_mean                                 0.370997
# area_mean                                      0.307308
# smoothness_mean                                0.472212
#
#                  concavity_worst * smoothness_worst / 1  \
# radius_mean                                    0.468807
# texture_mean                                   0.287665
# perimeter_mean                                 0.507370
# area_mean                                      0.455909
# smoothness_mean                                0.526528
#
#                  compactness_mean * smoothness_mean / 1  \
# radius_mean                                    0.446655
# texture_mean                                   0.185172
# perimeter_mean                                 0.497610
# area_mean                                      0.442813
# smoothness_mean                                0.768112
#
#                  concave points_worst * texture_worst / 1  \
# radius_mean                                      0.706282
# texture_mean                                     0.530882
# perimeter_mean                                   0.731313
# area_mean                                        0.687910
# smoothness_mean                                  0.433379
#
#                  compactness_mean * radius_mean / 1  \
# radius_mean                                0.765649
# texture_mean                               0.303062
# perimeter_mean                             0.803677
# area_mean                                  0.768776
# smoothness_mean                            0.530560
#
#                  concave points_worst * radius_mean / 1  \
# radius_mean                                    0.884770
# texture_mean                                   0.328013
# perimeter_mean                                 0.904172
# area_mean                                      0.885318
# smoothness_mean                                0.412303
#
#                  radius_mean * texture_worst / 1  \
# radius_mean                             0.816652
# texture_mean                            0.743264
# perimeter_mean                          0.819498
# area_mean                               0.807379
# smoothness_mean                         0.140417
#
#                  area_worst * compactness_mean / 1  \
# radius_mean                               0.831832
# texture_mean                              0.321197
# perimeter_mean                            0.858297
# area_mean                                 0.858256
# smoothness_mean                           0.412016
#
#                  compactness_mean * concave points_worst / 1
# radius_mean                                         0.631610
# texture_mean                                        0.283745
# perimeter_mean                                      0.674465
# area_mean                                           0.624956
# smoothness_mean                                     0.566436
#
# [5 rows x 420 columns]

# %%
# Select columns with correlations above threshold
col_to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
print('Columns with correlation > {}:\n-{}'.format(threshold,"\n-".join(col_to_drop)))
# Out:
# Columns with correlation > 0.9:
# -perimeter_mean
# -area_mean
# -concave points_mean
# -radius_worst
# -texture_worst
# -perimeter_worst
# -area_worst
# -concave points_worst
# -area_mean * concave points_mean
# -perimeter_worst * smoothness_worst
# -fractal_dimension_mean * texture_worst
# -area_worst * concave points_worst
# -concave points_worst * concavity_worst
# -concavity_mean * smoothness_worst
# -concavity_worst * smoothness_mean
# -area_worst * radius_mean
# -compactness_worst * smoothness_worst
# -concavity_mean * symmetry_mean
# -concave points_worst * symmetry_worst
# -compactness_mean * perimeter_worst
# -area_mean * fractal_dimension_mean
# -fractal_dimension_mean * fractal_dimension_worst
# -radius_worst * smoothness_mean
# -area_mean * compactness_mean
# -fractal_dimension_mean * smoothness_worst
# -fractal_dimension_worst * perimeter_mean
# -concavity_mean * symmetry_worst
# -concave points_worst * symmetry_mean
# -fractal_dimension_worst * symmetry_mean
# -concave points_worst * perimeter_mean
# -concave points_worst * fractal_dimension_worst
# -perimeter_worst * texture_worst
# -compactness_worst * texture_mean
# -compactness_worst * radius_worst
# -concave points_mean * radius_mean
# -concavity_mean * texture_worst
# -concavity_worst * texture_worst
# -concavity_worst * symmetry_mean
# -area_worst * perimeter_mean
# -area_mean * area_worst
# -concave points_mean * concave points_worst
# -smoothness_mean * texture_worst
# -concave points_worst * concavity_mean
# -compactness_mean * fractal_dimension_mean
# -concave points_mean * smoothness_worst
# -area_worst * radius_worst
# -perimeter_worst * symmetry_mean
# -area_mean * smoothness_mean
# -concave points_mean * concavity_worst
# -compactness_mean * radius_worst
# -radius_worst * symmetry_mean
# -compactness_mean * perimeter_mean
# -perimeter_mean * perimeter_worst
# -fractal_dimension_mean * texture_mean
# -concavity_mean * fractal_dimension_worst
# -radius_mean * radius_worst
# -concavity_mean * smoothness_mean
# -compactness_worst * concavity_mean
# -concavity_mean * perimeter_worst
# -symmetry_worst * texture_mean
# -fractal_dimension_worst * radius_worst
# -concave points_worst * radius_worst
# -radius_mean * smoothness_mean
# -smoothness_mean * texture_mean
# -fractal_dimension_worst * texture_worst
# -concavity_worst * texture_mean
# -area_worst * texture_mean
# -compactness_mean * concavity_mean
# -concave points_worst * fractal_dimension_mean
# -compactness_worst * concave points_mean
# -area_mean * symmetry_worst
# -concavity_mean * concavity_worst
# -compactness_mean * compactness_worst
# -perimeter_worst * texture_mean
# -concave points_mean * smoothness_mean
# -compactness_worst * fractal_dimension_worst
# -smoothness_worst * texture_worst
# -perimeter_mean * texture_mean
# -concavity_mean * fractal_dimension_mean
# -area_worst * concavity_mean
# -compactness_mean * texture_mean
# -area_mean * texture_worst
# -fractal_dimension_mean * perimeter_mean
# -compactness_worst * concavity_worst
# -perimeter_mean * smoothness_worst
# -fractal_dimension_mean * radius_worst
# -perimeter_mean * radius_mean
# -concave points_mean * symmetry_worst
# -smoothness_worst * texture_mean
# -symmetry_mean * texture_worst
# -fractal_dimension_worst * perimeter_worst
# -concave points_worst * perimeter_worst
# -radius_mean * symmetry_worst
# -area_mean * perimeter_mean
# -perimeter_worst * radius_mean
# -area_mean * symmetry_mean
# -compactness_worst * texture_worst
# -area_worst * smoothness_worst
# -area_mean * fractal_dimension_worst
# -area_mean * radius_worst
# -concavity_worst * radius_worst
# -concave points_mean * radius_worst
# -concave points_worst * smoothness_mean
# -concavity_mean * radius_mean
# -concavity_worst * radius_mean
# -concave points_mean * texture_worst
# -concavity_worst * fractal_dimension_mean
# -concave points_mean * perimeter_mean
# -area_worst * compactness_worst
# -concavity_worst * perimeter_mean
# -compactness_mean * concave points_mean
# -area_worst * symmetry_mean
# -compactness_worst * concave points_worst
# -perimeter_mean * symmetry_worst
# -area_worst * concave points_mean
# -fractal_dimension_worst * radius_mean
# -compactness_mean * smoothness_worst
# -compactness_mean * texture_worst
# -fractal_dimension_worst * smoothness_mean
# -perimeter_worst * radius_worst
# -radius_mean * smoothness_worst
# -compactness_mean * fractal_dimension_worst
# -perimeter_mean * symmetry_mean
# -radius_mean * symmetry_mean
# -area_worst * symmetry_worst
# -compactness_mean * symmetry_mean
# -fractal_dimension_mean * perimeter_worst
# -compactness_worst * fractal_dimension_mean
# -perimeter_mean * radius_worst
# -fractal_dimension_mean * radius_mean
# -fractal_dimension_mean * smoothness_mean
# -smoothness_mean * symmetry_worst
# -area_mean * smoothness_worst
# -area_worst * texture_worst
# -smoothness_worst * symmetry_mean
# -texture_mean * texture_worst
# -area_mean * concave points_worst
# -concavity_mean * perimeter_mean
# -fractal_dimension_worst * symmetry_worst
# -area_mean * concavity_mean
# -area_mean * perimeter_worst
# -concavity_mean * radius_worst
# -area_mean * radius_mean
# -perimeter_worst * symmetry_worst
# -area_mean * texture_mean
# -concavity_worst * fractal_dimension_worst
# -concave points_mean * fractal_dimension_worst
# -perimeter_mean * texture_worst
# -perimeter_mean * smoothness_mean
# -concave points_mean * texture_mean
# -area_mean * compactness_worst
# -compactness_worst * perimeter_worst
# -compactness_worst * radius_mean
# -concave points_mean * concavity_mean
# -fractal_dimension_worst * smoothness_worst
# -area_worst * fractal_dimension_worst
# -perimeter_worst * smoothness_mean
# -compactness_worst * smoothness_mean
# -concave points_worst * smoothness_worst
# -concave points_mean * fractal_dimension_mean
# -area_worst * smoothness_mean
# -symmetry_mean * symmetry_worst
# -radius_mean * texture_mean
# -area_worst * perimeter_worst
# -fractal_dimension_mean * symmetry_worst
# -area_mean * concavity_worst
# -radius_worst * texture_worst
# -concavity_worst * symmetry_worst
# -concavity_mean * texture_mean
# -compactness_mean * symmetry_worst
# -area_worst * concavity_worst
# -radius_worst * smoothness_worst
# -compactness_mean * concavity_worst
# -concave points_mean * perimeter_worst
# -concavity_worst * perimeter_worst
# -concave points_mean * symmetry_mean
# -smoothness_mean * smoothness_worst
# -area_worst * fractal_dimension_mean
# -concave points_worst * texture_mean
# -compactness_worst * perimeter_mean
# -compactness_worst * symmetry_mean
# -compactness_worst * symmetry_worst
# -concavity_worst * smoothness_worst
# -compactness_mean * smoothness_mean
# -concave points_worst * texture_worst
# -compactness_mean * radius_mean
# -concave points_worst * radius_mean
# -radius_mean * texture_worst
# -area_worst * compactness_mean
# -compactness_mean * concave points_worst
# -radius_mean / 1
# -texture_mean / 1
# -perimeter_mean / 1
# -area_mean / 1
# -smoothness_mean / 1
# -compactness_mean / 1
# -concavity_mean / 1
# -concave points_mean / 1
# -symmetry_mean / 1
# -fractal_dimension_mean / 1
# -radius_worst / 1
# -texture_worst / 1
# -perimeter_worst / 1
# -area_worst / 1
# -smoothness_worst / 1
# -compactness_worst / 1
# -concavity_worst / 1
# -concave points_worst / 1
# -symmetry_worst / 1
# -fractal_dimension_worst / 1
# -area_mean * concave points_mean / 1
# -perimeter_worst * smoothness_worst / 1
# -fractal_dimension_mean * texture_worst / 1
# -area_worst * concave points_worst / 1
# -concave points_worst * concavity_worst / 1
# -concavity_mean * smoothness_worst / 1
# -concavity_worst * smoothness_mean / 1
# -area_worst * radius_mean / 1
# -compactness_worst * smoothness_worst / 1
# -radius_worst * texture_mean / 1
# -concavity_mean * symmetry_mean / 1
# -concave points_worst * symmetry_worst / 1
# -compactness_mean * perimeter_worst / 1
# -area_mean * fractal_dimension_mean / 1
# -symmetry_worst * texture_worst / 1
# -fractal_dimension_mean * symmetry_mean / 1
# -fractal_dimension_mean * fractal_dimension_worst / 1
# -radius_worst * smoothness_mean / 1
# -area_mean * compactness_mean / 1
# -fractal_dimension_mean * smoothness_worst / 1
# -fractal_dimension_worst * perimeter_mean / 1
# -concavity_mean * symmetry_worst / 1
# -concave points_worst * symmetry_mean / 1
# -fractal_dimension_worst * symmetry_mean / 1
# -concave points_worst * perimeter_mean / 1
# -concave points_worst * fractal_dimension_worst / 1
# -perimeter_worst * texture_worst / 1
# -compactness_worst * texture_mean / 1
# -compactness_worst * radius_worst / 1
# -smoothness_mean * symmetry_mean / 1
# -concave points_mean * radius_mean / 1
# -concavity_mean * texture_worst / 1
# -concavity_worst * texture_worst / 1
# -radius_worst * symmetry_worst / 1
# -concavity_worst * symmetry_mean / 1
# -area_worst * perimeter_mean / 1
# -area_mean * area_worst / 1
# -concave points_mean * concave points_worst / 1
# -smoothness_mean * texture_worst / 1
# -concave points_worst * concavity_mean / 1
# -compactness_mean * fractal_dimension_mean / 1
# -concave points_mean * smoothness_worst / 1
# -area_worst * radius_worst / 1
# -perimeter_worst * symmetry_mean / 1
# -area_mean * smoothness_mean / 1
# -concave points_mean * concavity_worst / 1
# -compactness_mean * radius_worst / 1
# -radius_worst * symmetry_mean / 1
# -compactness_mean * perimeter_mean / 1
# -perimeter_mean * perimeter_worst / 1
# -fractal_dimension_mean * texture_mean / 1
# -concavity_mean * fractal_dimension_worst / 1
# -radius_mean * radius_worst / 1
# -concavity_mean * smoothness_mean / 1
# -compactness_worst * concavity_mean / 1
# -concavity_mean * perimeter_worst / 1
# -fractal_dimension_worst * texture_mean / 1
# -symmetry_worst * texture_mean / 1
# -fractal_dimension_worst * radius_worst / 1
# -concave points_worst * radius_worst / 1
# -radius_mean * smoothness_mean / 1
# -smoothness_mean * texture_mean / 1
# -fractal_dimension_worst * texture_worst / 1
# -concavity_worst * texture_mean / 1
# -area_worst * texture_mean / 1
# -compactness_mean * concavity_mean / 1
# -concave points_worst * fractal_dimension_mean / 1
# -compactness_worst * concave points_mean / 1
# -area_mean * symmetry_worst / 1
# -concavity_mean * concavity_worst / 1
# -compactness_mean * compactness_worst / 1
# -perimeter_worst * texture_mean / 1
# -concave points_mean * smoothness_mean / 1
# -compactness_worst * fractal_dimension_worst / 1
# -smoothness_worst * texture_worst / 1
# -symmetry_mean * texture_mean / 1
# -perimeter_mean * texture_mean / 1
# -concavity_mean * fractal_dimension_mean / 1
# -area_worst * concavity_mean / 1
# -compactness_mean * texture_mean / 1
# -area_mean * texture_worst / 1
# -fractal_dimension_mean * perimeter_mean / 1
# -compactness_worst * concavity_worst / 1
# -perimeter_mean * smoothness_worst / 1
# -fractal_dimension_mean * radius_worst / 1
# -perimeter_mean * radius_mean / 1
# -concave points_mean * symmetry_worst / 1
# -smoothness_worst * texture_mean / 1
# -symmetry_mean * texture_worst / 1
# -fractal_dimension_worst * perimeter_worst / 1
# -concave points_worst * perimeter_worst / 1
# -radius_mean * symmetry_worst / 1
# -area_mean * perimeter_mean / 1
# -perimeter_worst * radius_mean / 1
# -area_mean * symmetry_mean / 1
# -compactness_worst * texture_worst / 1
# -area_worst * smoothness_worst / 1
# -area_mean * fractal_dimension_worst / 1
# -area_mean * radius_worst / 1
# -concavity_worst * radius_worst / 1
# -concave points_mean * radius_worst / 1
# -concave points_worst * smoothness_mean / 1
# -concavity_mean * radius_mean / 1
# -concavity_worst * radius_mean / 1
# -concave points_mean * texture_worst / 1
# -concavity_worst * fractal_dimension_mean / 1
# -concave points_mean * perimeter_mean / 1
# -area_worst * compactness_worst / 1
# -concavity_worst * perimeter_mean / 1
# -compactness_mean * concave points_mean / 1
# -area_worst * symmetry_mean / 1
# -compactness_worst * concave points_worst / 1
# -perimeter_mean * symmetry_worst / 1
# -area_worst * concave points_mean / 1
# -fractal_dimension_worst * radius_mean / 1
# -compactness_mean * smoothness_worst / 1
# -compactness_mean * texture_worst / 1
# -fractal_dimension_worst * smoothness_mean / 1
# -perimeter_worst * radius_worst / 1
# -radius_mean * smoothness_worst / 1
# -smoothness_worst * symmetry_worst / 1
# -compactness_mean * fractal_dimension_worst / 1
# -perimeter_mean * symmetry_mean / 1
# -radius_mean * symmetry_mean / 1
# -area_worst * symmetry_worst / 1
# -compactness_mean * symmetry_mean / 1
# -fractal_dimension_mean * perimeter_worst / 1
# -compactness_worst * fractal_dimension_mean / 1
# -perimeter_mean * radius_worst / 1
# -fractal_dimension_mean * radius_mean / 1
# -fractal_dimension_mean * smoothness_mean / 1
# -smoothness_mean * symmetry_worst / 1
# -area_mean * smoothness_worst / 1
# -area_worst * texture_worst / 1
# -smoothness_worst * symmetry_mean / 1
# -texture_mean * texture_worst / 1
# -area_mean * concave points_worst / 1
# -concavity_mean * perimeter_mean / 1
# -fractal_dimension_worst * symmetry_worst / 1
# -area_mean * concavity_mean / 1
# -area_mean * perimeter_worst / 1
# -concavity_mean * radius_worst / 1
# -area_mean * radius_mean / 1
# -perimeter_worst * symmetry_worst / 1
# -area_mean * texture_mean / 1
# -concavity_worst * fractal_dimension_worst / 1
# -concave points_mean * fractal_dimension_worst / 1
# -perimeter_mean * texture_worst / 1
# -perimeter_mean * smoothness_mean / 1
# -concave points_mean * texture_mean / 1
# -area_mean * compactness_worst / 1
# -compactness_worst * perimeter_worst / 1
# -compactness_worst * radius_mean / 1
# -concave points_mean * concavity_mean / 1
# -fractal_dimension_worst * smoothness_worst / 1
# -area_worst * fractal_dimension_worst / 1
# -perimeter_worst * smoothness_mean / 1
# -compactness_worst * smoothness_mean / 1
# -concave points_worst * smoothness_worst / 1
# -concave points_mean * fractal_dimension_mean / 1
# -area_worst * smoothness_mean / 1
# -symmetry_mean * symmetry_worst / 1
# -radius_mean * texture_mean / 1
# -area_worst * perimeter_worst / 1
# -fractal_dimension_mean * symmetry_worst / 1
# -area_mean * concavity_worst / 1
# -radius_worst * texture_worst / 1
# -concavity_worst * symmetry_worst / 1
# -concavity_mean * texture_mean / 1
# -compactness_mean * symmetry_worst / 1
# -area_worst * concavity_worst / 1
# -radius_worst * smoothness_worst / 1
# -compactness_mean * concavity_worst / 1
# -concave points_mean * perimeter_worst / 1
# -concavity_worst * perimeter_worst / 1
# -concave points_mean * symmetry_mean / 1
# -smoothness_mean * smoothness_worst / 1
# -area_worst * fractal_dimension_mean / 1
# -concave points_worst * texture_mean / 1
# -compactness_worst * perimeter_mean / 1
# -compactness_worst * symmetry_mean / 1
# -compactness_worst * symmetry_worst / 1
# -concavity_worst * smoothness_worst / 1
# -compactness_mean * smoothness_mean / 1
# -concave points_worst * texture_worst / 1
# -compactness_mean * radius_mean / 1
# -concave points_worst * radius_mean / 1
# -radius_mean * texture_worst / 1
# -area_worst * compactness_mean / 1
# -compactness_mean * concave points_worst / 1

# %%
feature_matrix_dropcorr = feature_matrix.drop(columns = col_to_drop)
feature_matrix_dropcorr.head()
# Out:
#        radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# id
# 8670         15.46         19.48          0.10920           0.12230
# 8913         12.89         13.12          0.06955           0.03729
# 8915         14.96         19.10          0.08992           0.09823
# 9047         12.94         16.17          0.09879           0.08836
# 85715        13.17         18.66          0.11580           0.12310
#
#        concavity_mean  symmetry_mean  fractal_dimension_mean  \
# id
# 8670          0.14660         0.1931                 0.05796
# 8913          0.02260         0.1337                 0.05581
# 8915          0.05940         0.1879                 0.05852
# 9047          0.03296         0.1735                 0.06200
# 85715         0.12260         0.2128                 0.06777
#
#        smoothness_worst  compactness_worst  concavity_worst  symmetry_worst  \
# id
# 8670            0.15460             0.2394           0.3791          0.2837
# 8913            0.09616             0.1147           0.1186          0.2309
# 8915            0.13130             0.3030           0.1804          0.2962
# 9047            0.11720             0.1958           0.1810          0.3297
# 85715           0.17860             0.4166           0.5006          0.3900
#
#        fractal_dimension_worst  radius_worst * texture_mean  \
# id
# 8670                   0.08019                     375.1848
# 8913                   0.06915                     178.6944
# 8915                   0.08472                     310.3750
# 9047                   0.07834                     224.1162
# 85715                  0.11790                     292.4022
#
#        symmetry_worst * texture_worst  fractal_dimension_mean * symmetry_mean  \
# id
# 8670                         7.376200                                0.011192
# 8913                         3.588186                                0.007462
# 8915                         7.757478                                0.010996
# 9047                         7.589694                                0.010757
# 85715                       10.900500                                0.014421
#
#        smoothness_mean * symmetry_mean  radius_worst * symmetry_worst  \
# id
# 8670                          0.021087                       5.464062
# 8913                          0.009299                       3.144858
# 8915                          0.016896                       4.813250
# 9047                          0.017140                       4.569642
# 85715                         0.024642                       6.111300
#
#        fractal_dimension_worst * texture_mean  symmetry_mean * texture_mean  \
# id
# 8670                                 1.562101                      3.761588
# 8913                                 0.907248                      1.754144
# 8915                                 1.618152                      3.588890
# 9047                                 1.266758                      2.805495
# 85715                                2.200014                      3.970848
#
#        smoothness_worst * symmetry_worst
# id
# 8670                            0.043860
# 8913                            0.022203
# 8915                            0.038891
# 9047                            0.038641
# 85715                           0.069654

# %%
# Remove columns with missing values
feature_matrix_dropcorr.replace([np.inf, -np.inf], np.nan, inplace=True)
col_without_nan = feature_matrix_dropcorr.columns[~feature_matrix_dropcorr.isna().any()]
feature_matrix_dropcorr_dropnan = feature_matrix_dropcorr[col_without_nan]

# Remove columns with too little information (less than ten distinct values)
selection.remove_low_information_features(feature_matrix_dropcorr_dropnan)

feature_matrix_dropcorr_dropnan.shape
# Out:
# (569, 20)

# %% [markdown]
# ### Add diagnosis column back to feature matrix

# %%
# Convert (M=malignant, B=benign) to (1,0)

def convert_to_num(diag):
    return 0 if diag =='B' else 1

df['diagnosis'] = df['diagnosis'].apply(convert_to_num)
df_outcomes = df.loc[:,['id','diagnosis']]
df_outcomes.set_index('id',inplace=True)
df_outcomes.head()
# Out:
#           diagnosis
# id
# 842302            1
# 842517            1
# 84300903          1
# 84348301          1
# 84358402          1

# %%
df_feature_matrix_outcomes = pd.merge(feature_matrix_dropcorr_dropnan,df_outcomes,
                                      left_index=True, right_index=True)
df_feature_matrix_outcomes.head()
# Out:
#        radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# id
# 8670         15.46         19.48          0.10920           0.12230
# 8913         12.89         13.12          0.06955           0.03729
# 8915         14.96         19.10          0.08992           0.09823
# 9047         12.94         16.17          0.09879           0.08836
# 85715        13.17         18.66          0.11580           0.12310
#
#        concavity_mean  symmetry_mean  fractal_dimension_mean  \
# id
# 8670          0.14660         0.1931                 0.05796
# 8913          0.02260         0.1337                 0.05581
# 8915          0.05940         0.1879                 0.05852
# 9047          0.03296         0.1735                 0.06200
# 85715         0.12260         0.2128                 0.06777
#
#        smoothness_worst  compactness_worst  concavity_worst  ...  \
# id                                                           ...
# 8670            0.15460             0.2394           0.3791  ...
# 8913            0.09616             0.1147           0.1186  ...
# 8915            0.13130             0.3030           0.1804  ...
# 9047            0.11720             0.1958           0.1810  ...
# 85715           0.17860             0.4166           0.5006  ...
#
#        fractal_dimension_worst  radius_worst * texture_mean  \
# id
# 8670                   0.08019                     375.1848
# 8913                   0.06915                     178.6944
# 8915                   0.08472                     310.3750
# 9047                   0.07834                     224.1162
# 85715                  0.11790                     292.4022
#
#        symmetry_worst * texture_worst  fractal_dimension_mean * symmetry_mean  \
# id
# 8670                         7.376200                                0.011192
# 8913                         3.588186                                0.007462
# 8915                         7.757478                                0.010996
# 9047                         7.589694                                0.010757
# 85715                       10.900500                                0.014421
#
#        smoothness_mean * symmetry_mean  radius_worst * symmetry_worst  \
# id
# 8670                          0.021087                       5.464062
# 8913                          0.009299                       3.144858
# 8915                          0.016896                       4.813250
# 9047                          0.017140                       4.569642
# 85715                         0.024642                       6.111300
#
#        fractal_dimension_worst * texture_mean  symmetry_mean * texture_mean  \
# id
# 8670                                 1.562101                      3.761588
# 8913                                 0.907248                      1.754144
# 8915                                 1.618152                      3.588890
# 9047                                 1.266758                      2.805495
# 85715                                2.200014                      3.970848
#
#        smoothness_worst * symmetry_worst  diagnosis
# id
# 8670                            0.043860          1
# 8913                            0.022203          0
# 8915                            0.038891          0
# 9047                            0.038641          0
# 85715                           0.069654          1
#
# [5 rows x 21 columns]

# %% [markdown]
# ## K-fold cross validation

# %%
feature_names = df_feature_matrix_outcomes.columns.tolist()[:-1]
X = df_feature_matrix_outcomes[feature_names].values
y = df_feature_matrix_outcomes['diagnosis'].values

# %%
def cross_validatoin(fold, model, X, y):
    
    sensitivity=[]
    specificity=[]
    accuracy=[]
    F1scores=[]
    
    kf = KFold(n_splits=fold,shuffle=True) 
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index] 
        y_train, y_test = y[train_index], y[test_index]
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        cm = confusion_matrix(y_test,y_pred)
        sensitivity.append(cm[0,0]/(cm[0,0]+cm[1,0]))
        specificity.append(cm[1,1]/(cm[1,1]+cm[0,1]))
        accuracy.append(accuracy_score(y_test,y_pred))
        F1scores.append(f1_score(y_test, y_pred, pos_label=1))
        
    return [np.mean(sensitivity),np.mean(specificity),np.mean(accuracy),np.mean(F1scores)]

# %%
d_Model_eva = {} # create dictionary to collect results
fold = 10  # n-fold cross validation

# %% [markdown]
# ### Apply Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
d_Model_eva['Random Forest'] = cross_validatoin(fold, RandomForestClassifier(), X, y)

# %% [markdown]
# ### Output

# %%
df_eva = pd.DataFrame(d_Model_eva, index=['Sensitivity','Specificity','Accuracy','F1-score'])
df_eva.round(3)
# Out:
#              Random Forest
# Sensitivity          0.961
# Specificity          0.967
# Accuracy             0.961
# F1-score             0.945

# %% [markdown]
# ## Evaluate the impact of each feature with SHAP Values
# Link to [SHAP (SHapley Additive exPlanations)](https://www.kaggle.com/dansbecker/shap-values)

# %%
import shap

explainer = shap.TreeExplainer(RandomForestClassifier().fit(X,y)) # Create object that can calculate shap values
shap_values = explainer.shap_values(X) 

shap.summary_plot(shap_values[1], X, feature_names=feature_names,plot_type="bar")

# %%
shap.summary_plot(shap_values[1],X,feature_names=feature_names)

# %%
# Create dataframe of feature importance according to SHAP
shap_sum = np.abs(shap_values[1]).mean(axis=0)
df_importance = pd.DataFrame([feature_names, shap_sum.tolist()]).T
df_importance.columns = ['Features','SHAP_importance']
df_importance = df_importance.sort_values('SHAP_importance', ascending=False)
df_importance.head()
# Out:
#                           Features SHAP_importance
# 0                      radius_mean        0.121778
# 16   radius_worst * symmetry_worst        0.111163
# 9                  concavity_worst       0.0661231
# 12     radius_worst * texture_mean       0.0583683
# 13  symmetry_worst * texture_worst        0.042192

# %% [markdown]
# ### Distribution of the most impactful features

# %%
# get the top 6 and bottom 6 most impactful features
top_features = df_importance.head(6)['Features'].tolist()

# %%
def plot_feature(df_feature_matrix_outcomes,sel_features):
    
    plt.figure(figsize = (20, 10))
    for i, sel_feature in enumerate(sel_features):

        # create a new subplot for each source
        plt.subplot(2, 3, i + 1)

        # KDE plot of the most impactful feature 
        sns.kdeplot(df_feature_matrix_outcomes.loc[df_feature_matrix_outcomes['diagnosis'] == 1,sel_feature],color='red',label = 'malignant')
        sns.kdeplot(df_feature_matrix_outcomes.loc[df_feature_matrix_outcomes['diagnosis'] == 0,sel_feature],color='blue', label = 'benign')

        # Labeling of plot
        plt.xlabel(sel_feature)

# %%
plot_feature(df_feature_matrix_outcomes,top_features)
