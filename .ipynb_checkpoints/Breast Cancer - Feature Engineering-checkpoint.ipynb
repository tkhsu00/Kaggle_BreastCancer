# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns #for plotting

from warnings import simplefilter  # import warnings filter
pd.options.mode.chained_assignment = None  #hide any pandas warnings
simplefilter(action='ignore', category=FutureWarning)  # ignore all future warnings
np.random.seed(123) #ensure reproducibility

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# #### Column Description [Link](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data#data.csv)
# id: ID number
# diagnosis: The diagnosis of breast tissues (M = malignant, B = benign)
# radius_mean: mean of distances from center to points on the perimeter
# texture_mean: standard deviation of gray-scale values
# perimeter_mean: mean size of the core tumor
# area_mean
# smoothness_mean: mean of local variation in radius lengths
# compactness_mean: mean of perimeter^2 / area - 1.0
# concavity_mean: mean of severity of concave portions of the contour
# concave points_mean: mean for number of concave portions of the contour
# symmetry_mean
# fractal_dimension_mean: mean for "coastline approximation" - 1
# radius_se: standard error for the mean of distances from center to points on the perimeter
# texture_se: standard error for standard deviation of gray-scale values
# perimeter_se
# area_se
# smoothness_se: standard error for local variation in radius lengths
# compactness_se: standard error for perimeter^2 / area - 1.0
# concavity_se: standard error for severity of concave portions of the contour
# concave points_se: standard error for number of concave portions of the contour
# symmetry_se
# fractal_dimension_se: standard error for "coastline approximation" - 1
# radius_worst: "worst" or largest mean value for mean of distances from center to points on the perimeter
# texture_worst: "worst" or largest mean value for standard deviation of gray-scale values
# perimeter_worst
# area_worst
# smoothness_worst: "worst" or largest mean value for local variation in radius lengths
# compactness_worst: "worst" or largest mean value for perimeter^2 / area - 1.0
# concavity_worst: "worst" or largest mean value for severity of concave portions of the contour
# concave points_worst: "worst" or largest mean value for number of concave portions of the contour
# symmetry_worst
# fractal_dimension_worst: "worst" or largest mean value for "coastline approximation" - 1

# %%
# rearrange columns; remove columns of standard error and Unnamed: 32
data_columns = [df.columns[0]]+list(df.columns[2:-1])
data_columns = [c for c in data_columns if not c.endswith('_se')]
df_data = df[data_columns]
df_data.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Automated feature engineering

# %%
# featuretools for automated feature engineering
import featuretools as ft

# %%
# Create new entityset
es = ft.EntitySet(id = 'breastcancer')

# Create an entity from the breast cancer dataframe
es = es.entity_from_dataframe(entity_id = 'breastcancer', dataframe = df_data,index = 'id')

# %%
feature_matrix, feature_defs = ft.dfs(entityset = es, target_entity = 'breastcancer',
                                      trans_primitives = ['multiply_numeric'])

# %%
feature_matrix.head()
# Out:
#        radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# id
# 8670         15.46         19.48          101.70      748.9          0.10920
# 8913         12.89         13.12           81.89      515.9          0.06955
# 8915         14.96         19.10           97.03      687.3          0.08992
# 9047         12.94         16.17           83.18      507.6          0.09879
# 85715        13.17         18.66           85.98      534.6          0.11580
#
#        compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# id
# 8670            0.12230         0.14660              0.08087         0.1931
# 8913            0.03729         0.02260              0.01171         0.1337
# 8915            0.09823         0.05940              0.04819         0.1879
# 9047            0.08836         0.03296              0.02390         0.1735
# 85715           0.12310         0.12260              0.07340         0.2128
#
#        fractal_dimension_mean  ...  area_worst * perimeter_worst  \
# id                             ...
# 8670                  0.05796  ...                    144384.400
# 8913                  0.05581  ...                     50429.800
# 8915                  0.05852  ...                     88349.180
# 9047                  0.06200  ...                     52100.921
# 85715                 0.06777  ...                     78066.320
#
#        compactness_worst * fractal_dimension_mean  \
# id
# 8670                                     0.013876
# 8913                                     0.006401
# 8915                                     0.017732
# 9047                                     0.012140
# 85715                                    0.028233
#
#        fractal_dimension_mean * symmetry_mean  symmetry_worst * texture_worst  \
# id
# 8670                                 0.011192                        7.376200
# 8913                                 0.007462                        3.588186
# 8915                                 0.010996                        7.757478
# 9047                                 0.010757                        7.589694
# 85715                                0.014421                       10.900500
#
#        compactness_mean * radius_worst  area_mean * smoothness_mean  \
# id
# 8670                          2.355498                    81.779880
# 8913                          0.507890                    35.880845
# 8915                          1.596237                    61.802016
# 9047                          1.224670                    50.145804
# 85715                         1.928977                    61.906680
#
#        perimeter_worst * smoothness_mean  area_mean * perimeter_mean  \
# id
# 8670                           13.639080                   76163.130
# 8913                            6.078670                   42247.051
# 8915                            9.810272                   66688.719
# 9047                            8.860475                   42222.168
# 85715                          11.904240                   45964.908
#
#        perimeter_mean * radius_mean  fractal_dimension_worst * perimeter_worst
# id
# 8670                      1572.2820                                  10.015731
# 8913                      1055.5621                                   6.043710
# 8915                      1451.5688                                   9.242952
# 9047                      1076.3492                                   7.026315
# 85715                     1132.3566                                  12.120120
#
# [5 rows x 210 columns]

# %% [markdown]
# ### Remove Highly Correlated Columns
# Drop Highly Correlated Features, the code is adapted from [work](https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/) by Chris Albon.

# %%
# Define the threshold for removing correlated variables
threshold = 0.9

# %%
# Get correlation of each variables
corr_matrix = feature_matrix.corr().abs()
# Upper triangle of correlations
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper.head()

# %%
# Select columns with correlations above threshold
col_to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
print('Columns with correlation > {}:\n-{}'.format(threshold,"\n-".join(col_to_drop)))

# %%
feature_matrix_dropcorr = feature_matrix.drop(columns = col_to_drop)
feature_matrix_dropcorr.shape
# Out:
# (569, 210)

# %%
# Remove columns with missing values
feature_matrix_dropcorr.replace([np.inf, -np.inf], np.nan, inplace=True)
col_without_nan = feature_matrix_dropcorr.columns[~feature_matrix_dropcorr.isna().any()]
feature_matrix_dropcorr_dropnan = feature_matrix_dropcorr[col_without_nan]
feature_matrix_dropcorr_dropnan.shape
# Out:
# (569, 210)

# %%
from featuretools import selection
selection.remove_low_information_features(feature_matrix_dropcorr_dropnan)
feature_matrix_dropcorr_dropnan.shape
# Out:
# (569, 210)

# %%
# Remove columns with too little information (less than ten distinct values)
col_with_dist_val = []
for col in feature_matrix_dropcorr_dropnan:
    if len(set(feature_matrix_dropcorr_dropnan[col].tolist()))>10:
        col_with_dist_val.append(col)
feature_matrix_dropcorr_dropnan_dropmonoval = feature_matrix_dropcorr_dropnan[col_with_dist_val]
feature_matrix_dropcorr_dropnan_dropmonoval.shape
# Out:
# (569, 210)

# %%
feature_matrix_dropcorr_dropnan_dropmonoval.to_csv('test.csv')

# %%
# Convert (M=malignant, B=benign) to (1,0)

def convert_to_num(diag):
    return 0 if diag =='B' else 1

outcomes = df['diagnosis'].apply(convert_to_num)

# %% [markdown]
# ## K-fold cross validation

# %%
feature_names = feature_matrix_dropcorr.columns.tolist()
X = feature_matrix_dropcorr_dropnan_dropmonoval.values
y = outcomes

# %%
from sklearn.model_selection import KFold 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

def cross_validatoin(fold, model, X, y):
    
    sensitivity=[]
    specificity=[]
    accuracy=[]
    F1scores=[]
    
    kf = KFold(n_splits=fold,shuffle=True) 
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index] 
        y_train, y_test = y[train_index], y[test_index]
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        cm = confusion_matrix(y_test,y_pred)
        sensitivity.append(cm[0,0]/(cm[0,0]+cm[1,0]))
        specificity.append(cm[1,1]/(cm[1,1]+cm[0,1]))
        accuracy.append(accuracy_score(y_test,y_pred))
        F1scores.append(f1_score(y_test, y_pred, pos_label=1))
        
    return [np.mean(sensitivity),np.mean(specificity),np.mean(accuracy),np.mean(F1scores)]

# %%
d_Model_eva = {} # create dictionary to collect results
fold = 10  # n-fold cross validation

# %% [markdown]
# ### 1. Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
d_Model_eva['Logistic Regression'] = cross_validatoin(fold, LogisticRegression(), X, y)

# %% [markdown]
# ### 2. Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
d_Model_eva['Decision Tree'] = cross_validatoin(fold, DecisionTreeClassifier(), X, y)

# %% [markdown]
# ### 3. Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
d_Model_eva['Random Forest'] = cross_validatoin(fold, RandomForestClassifier(), X, y)

# %% [markdown]
# ### Output

# %%
df_eva = pd.DataFrame(d_Model_eva, index=['Sensitivity','Specificity','Accuracy','F1-score'])
df_eva.round(3)
# Out:
#              Logistic Regression  Decision Tree  Random Forest
# Sensitivity                0.636          0.636          0.618
# Specificity                0.509          0.398          0.318
# Accuracy                   0.622          0.543          0.559
# F1-score                   0.169          0.390          0.228

# %%
print('{}-fold cross validation shows:'.format(fold))
for index, row in df_eva.iterrows():
    print("- {} has the best {} score = {:.3f}.".format(df_eva.loc[index,:].idxmax(axis=1), index,
                                         df_eva.loc[index, df_eva.loc[index,:].idxmax(axis=1)]))
# Out:
# 10-fold cross validation shows:
# - Decision Tree has the best Sensitivity score = 0.636.
# - Logistic Regression has the best Specificity score = 0.509.
# - Logistic Regression has the best Accuracy score = 0.622.
# - Decision Tree has the best F1-score score = 0.390.

# %% [markdown]
# ## Evaluate the impact of each feature with SHAP Values
# Link to [SHAP (SHapley Additive exPlanations)](https://www.kaggle.com/dansbecker/shap-values)

# %%
import shap

explainer = shap.TreeExplainer(RandomForestClassifier().fit(X,y)) # Create object that can calculate shap values
shap_values = explainer.shap_values(X) 

shap.summary_plot(shap_values[1], X, feature_names=feature_names,plot_type="bar")

# %%
shap.summary_plot(shap_values[1],X,feature_names=feature_names)

# %%
# Create dataframe of feature importance according to SHAP
shap_sum = np.abs(shap_values[1]).mean(axis=0)
df_importance = pd.DataFrame([feature_names, shap_sum.tolist()]).T
df_importance.columns = ['Features','SHAP_importance']
df_importance = df_importance.sort_values('SHAP_importance', ascending=False)
df_importance
# Out:
#                                           Features SHAP_importance
# 141                  symmetry_worst * texture_mean       0.0143022
# 60            concave points_mean * perimeter_mean       0.0132234
# 118               concavity_worst * symmetry_worst       0.0127969
# 61         compactness_worst * concave points_mean       0.0125256
# 207                     area_mean * perimeter_mean       0.0122633
# 197                  radius_worst * symmetry_worst       0.0116495
# 35                  area_worst * compactness_worst       0.0107094
# 186          fractal_dimension_mean * texture_mean       0.0100718
# 169                       area_mean * radius_worst      0.00998651
# 64           concave points_mean * smoothness_mean      0.00985924
# 37             concave points_mean * texture_worst      0.00979698
# 90          concave points_mean * smoothness_worst      0.00949924
# 132            compactness_mean * smoothness_worst      0.00882287
# 87            compactness_mean * compactness_worst      0.00881782
# 139                       area_mean * texture_mean      0.00873345
# 136                  perimeter_mean * radius_worst      0.00858748
# 74            fractal_dimension_mean * radius_mean      0.00856616
# 195               area_worst * concave points_mean      0.00816014
# 18                                  symmetry_worst      0.00812381
# 191                compactness_mean * texture_mean       0.0080978
# 14                                smoothness_worst      0.00808056
# 168            concave points_worst * radius_worst      0.00768854
# 30                     radius_worst * texture_mean      0.00768247
# 11                                   texture_worst      0.00768042
# 51         fractal_dimension_worst * symmetry_mean      0.00762252
# 7                              concave points_mean      0.00754203
# 183   concave points_mean * fractal_dimension_mean      0.00736628
# 177               compactness_mean * texture_worst      0.00723644
# 59           concave points_mean * concavity_worst      0.00723612
# 24                  compactness_mean * radius_mean      0.00712889
# ..                                             ...             ...
# 158              concave points_mean * radius_mean      0.00121714
# 154                    area_worst * perimeter_mean      0.00120233
# 137           concave points_worst * symmetry_mean      0.00112575
# 17                            concave points_worst      0.00110275
# 113              compactness_mean * perimeter_mean      0.00105608
# 53   concave points_worst * fractal_dimension_mean      0.00103304
# 206              perimeter_worst * smoothness_mean      0.00100241
# 170               compactness_worst * radius_worst      0.00100185
# 146            compactness_worst * perimeter_worst     0.000995488
# 32                      area_mean * symmetry_worst     0.000971911
# 13                                      area_worst     0.000801461
# 127       compactness_worst * concave points_worst     0.000770831
# 205                    area_mean * smoothness_mean     0.000697408
# 94                 concavity_mean * symmetry_worst     0.000570126
# 29         compactness_mean * concave points_worst     0.000512854
# 182             compactness_mean * concavity_worst     0.000473972
# 54                    area_worst * concavity_worst     0.000435693
# 111                concavity_worst * symmetry_mean     0.000422737
# 149       fractal_dimension_mean * smoothness_mean     0.000336465
# 144               concavity_mean * perimeter_worst     0.000332052
# 2                                   perimeter_mean     0.000328546
# 33                concavity_mean * concavity_worst     0.000318655
# 167           concave points_mean * symmetry_worst     0.000317243
# 28                  perimeter_worst * radius_worst               0
# 107       concavity_mean * fractal_dimension_worst               0
# 62             concave points_mean * symmetry_mean               0
# 97              compactness_worst * perimeter_mean               0
# 160             compactness_worst * concavity_mean               0
# 3                                        area_mean               0
# 125          fractal_dimension_mean * radius_worst               0
#
# [210 rows x 2 columns]

# %% [markdown]
# ### Distribution of the most impactful features

# %%
# Plot the distribution of top 6 features
top_features = df_importance.head(6)['Features'].tolist()

plt.figure(figsize = (20, 10))
for i, top_feature in enumerate(top_features):
    
    # create a new subplot for each source
    plt.subplot(2, 3, i + 1)

    # KDE plot of the most impactful feature 
    sns.kdeplot(df_data.loc[df_data['diagnosis'] == 1,top_feature],color='red',label = 'malignant')
    sns.kdeplot(df_data.loc[df_data['diagnosis'] == 0,top_feature],color='blue', label = 'benign')

    # Labeling of plot
    plt.xlabel(top_feature)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'diagnosis'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-ae27cd3d1a38> in <module>
#       9
#      10     # KDE plot of the most impactful feature
# ---> 11     sns.kdeplot(df_data.loc[df_data['diagnosis'] == 1,top_feature],color='red',label = 'malignant')
#      12     sns.kdeplot(df_data.loc[df_data['diagnosis'] == 0,top_feature],color='blue', label = 'benign')
#      13
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'diagnosis'

# %% [markdown]
# ### Distribution of the least impactful features

# %%
# Plot the distribution of bottom 6 features
top_features = df_importance.tail(6)['Features'].tolist()

plt.figure(figsize = (20, 10))
for i, top_feature in enumerate(top_features):
    
    # create a new subplot for each source
    plt.subplot(2, 3, i + 1)

    # KDE plot of the most impactful feature 
    sns.kdeplot(df_data.loc[df_data['diagnosis'] == 1,top_feature],color='red',label = 'malignant')
    sns.kdeplot(df_data.loc[df_data['diagnosis'] == 0,top_feature],color='blue', label = 'benign')

    # Labeling of plot
    plt.xlabel(top_feature)
